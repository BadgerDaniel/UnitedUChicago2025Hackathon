# %%
import os
import requests
from datetime import datetime
import pandas as pd
import holidays
from amadeus import Client, ResponseError

# %% [markdown]
# ## weather

# %%
def is_alert(code: int) -> bool:
    """
    Returns True if the weather condition code should trigger an alert, False otherwise.
    Optionally uses the description for more granularity.
    """

    # Thunderstorms (Group 2xx)
    if 200 <= code <= 232:
        return True  # All thunderstorms are potentially hazardous

    # Drizzle (Group 3xx)
    if 300 <= code <= 321:
        return False  # Generally light, not hazardous

    # Rain (Group 5xx)
    if code in {502, 503, 504, 511, 522, 531}:
        return True  # Heavy, extreme, or freezing rain
    elif 500 <= code <= 531:
        return False  # Light/moderate rain usually not alert-level

    # Snow (Group 6xx)
    if code in {602, 622, 616, 613, 620}:
        return True  # Heavy or mixed snow/ice conditions
    elif 600 <= code <= 622:
        return False  # Light snow/sleet usually advisory only

    # Atmosphere (Group 7xx)
    if code in {741, 762, 771, 781}:
        return True  # Fog, ash, squalls, tornado
    elif 700 <= code <= 781:
        return False  # Mist, haze, etc.

    # Clear & Clouds (Group 800-804)
    if code == 800:
        return False
    if 801 <= code <= 804:
        return False  # Cloud cover, no hazard

    return False  # Default to non-alert if unknown

# %%
city_coords = {
    "los angeles": (34.0522, -118.2437),
    "chicago": (41.8781, -87.6298),
    "houston": (29.7604, -95.3698),
    "denver": (39.7392, -104.9903),
    "newark": (40.7357, -74.1724),
    "san francisco": (37.7749, -122.4194),
    "washington dc": (38.9072, -77.0369),
 
}

# %%
coords = [value for key, value in city_coords.items()]
coords
# Out:
# [(34.0522, -118.2437),
#  (41.8781, -87.6298),
#  (29.7604, -95.3698),
#  (39.7392, -104.9903),
#  (40.7357, -74.1724),
#  (37.7749, -122.4194),
#  (38.9072, -77.0369)]

# %% [markdown]
# ## city

# %%
df_city = pd.DataFrame({
    'id': range(1, len(city_coords)+1),
    'city_name': city_coords.keys()})

df_city
# Out:
#    id      city_name
# 0   1    los angeles
# 1   2        chicago
# 2   3        houston
# 3   4         denver
# 4   5         newark
# 5   6  san francisco
# 6   7  washington dc

# %%
df_city.to_csv('data/intermediate/city.csv', index=False)

# %% [markdown]
# ### generate datetime

# %%
def get_city_id(df):
    def find_city(lat, lon, lookup):
        target = (lat, lon)
        return next((k for k, v in lookup.items() if v == target), None)
    
    city_to_id = dict(zip(df_city['city_name'], df_city['id']))
    df['city'] = df.apply(lambda row: find_city(row["lat"], row["lon"], city_coords), axis=1)
    df['city_id'] = df['city'].map(city_to_id)
    df = df.drop(columns='city')

    return df

# %%
from datetime import datetime, timedelta, timezone

# Start and end dates
start_date = datetime(2025, 1, 1, tzinfo=timezone.utc)
end_date = datetime(2025, 6, 22, tzinfo=timezone.utc)

# Generate list of timestamps at 00:00:00 UTC each day
timestamps = []
current_date = start_date
while current_date <= end_date:
    timestamps.append(int(current_date.timestamp()))
    current_date += timedelta(days=1)

print(timestamps)
# Out:
# [1735689600, 1735776000, 1735862400, 1735948800, 1736035200, 1736121600, 1736208000, 1736294400, 1736380800, 1736467200, 1736553600, 1736640000, 1736726400, 1736812800, 1736899200, 1736985600, 1737072000, 1737158400, 1737244800, 1737331200, 1737417600, 1737504000, 1737590400, 1737676800, 1737763200, 1737849600, 1737936000, 1738022400, 1738108800, 1738195200, 1738281600, 1738368000, 1738454400, 1738540800, 1738627200, 1738713600, 1738800000, 1738886400, 1738972800, 1739059200, 1739145600, 1739232000, 1739318400, 1739404800, 1739491200, 1739577600, 1739664000, 1739750400, 1739836800, 1739923200, 1740009600, 1740096000, 1740182400, 1740268800, 1740355200, 1740441600, 1740528000, 1740614400, 1740700800, 1740787200, 1740873600, 1740960000, 1741046400, 1741132800, 1741219200, 1741305600, 1741392000, 1741478400, 1741564800, 1741651200, 1741737600, 1741824000, 1741910400, 1741996800, 1742083200, 1742169600, 1742256000, 1742342400, 1742428800, 1742515200, 1742601600, 1742688000, 1742774400, 1742860800, 1742947200, 1743033600, 1743120000, 1743206400, 1743292800, 1743379200, 1743465600, 1743552000, 1743638400, 1743724800, 1743811200, 1743897600, 1743984000, 1744070400, 1744156800, 1744243200, 1744329600, 1744416000, 1744502400, 1744588800, 1744675200, 1744761600, 1744848000, 1744934400, 1745020800, 1745107200, 1745193600, 1745280000, 1745366400, 1745452800, 1745539200, 1745625600, 1745712000, 1745798400, 1745884800, 1745971200, 1746057600, 1746144000, 1746230400, 1746316800, 1746403200, 1746489600, 1746576000, 1746662400, 1746748800, 1746835200, 1746921600, 1747008000, 1747094400, 1747180800, 1747267200, 1747353600, 1747440000, 1747526400, 1747612800, 1747699200, 1747785600, 1747872000, 1747958400, 1748044800, 1748131200, 1748217600, 1748304000, 1748390400, 1748476800, 1748563200, 1748649600, 1748736000, 1748822400, 1748908800, 1748995200, 1749081600, 1749168000, 1749254400, 1749340800, 1749427200, 1749513600, 1749600000, 1749686400, 1749772800, 1749859200, 1749945600, 1750032000, 1750118400, 1750204800, 1750291200, 1750377600, 1750464000, 1750550400]

# %%
# Create DataFrames for city*date
df_coords = pd.DataFrame(coords, columns=["lat", "lon"])
df_times = pd.DataFrame(timestamps, columns=["timestamp"])

# Add keys to enable cartesian join
df_coords["key"] = 1
df_times["key"] = 1

# Cartesian product via merge
df_coord_time = pd.merge(df_coords, df_times, on="key").drop("key", axis=1)

# Optional: convert timestamp to readable date
df_coord_time["datetime"] = pd.to_datetime(df_coord_time["timestamp"], unit="s")

print(df_coord_time)
# Out:
#           lat       lon   timestamp   datetime
# 0     34.0522 -118.2437  1735689600 2025-01-01
# 1     34.0522 -118.2437  1735776000 2025-01-02
# 2     34.0522 -118.2437  1735862400 2025-01-03
# 3     34.0522 -118.2437  1735948800 2025-01-04
# 4     34.0522 -118.2437  1736035200 2025-01-05
# ...       ...       ...         ...        ...
# 1206  38.9072  -77.0369  1750204800 2025-06-18
# 1207  38.9072  -77.0369  1750291200 2025-06-19
# 1208  38.9072  -77.0369  1750377600 2025-06-20
# 1209  38.9072  -77.0369  1750464000 2025-06-21
# 1210  38.9072  -77.0369  1750550400 2025-06-22
#
# [1211 rows x 4 columns]

# %%
weather_api = os.getenv('OpenWeatherMap_API')

# %%
# weather_api = os.getenv('OpenWeatherMap_API')


# url = f"https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=39.099724&lon=-94.578331&dt=1750550400&&appid={weather_api}"

# response = requests.get(url)

# if response.status_code == 200:
#     data_w = response.json()
#     # print("Current temperature:", data['current']['temp'])
#     print(data_w)
# else:
#     print("Error:", response.status_code, response.text)

# %%
# import time
# import requests
# import pandas as pd

MAX_CALLS_PER_MINUTE = 60
MAX_TOTAL_CALLS = 500
SECONDS_BETWEEN_CALLS = 60 / MAX_CALLS_PER_MINUTE  # 1.0 seconds

total_calls = 0
start_time = time.time()
df_w = pd.DataFrame()  # Initialize your result dataframe

for index, row in df_coord_time.iterrows():
    if total_calls >= MAX_TOTAL_CALLS:
        print("Reached total API call limit (500).")
        break

    lat = row['lat']
    lon = row['lon']
    timestamp = row['timestamp']
    url = f"https://api.openweathermap.org/data/3.0/onecall/timemachine?lat={lat}&lon={lon}&dt={timestamp}&appid={weather_api}"

    response = requests.get(url)
    total_calls += 1

    if response.status_code == 200:
        data_w = response.json()
        print(index, data_w)
        
        weather_list = data_w['data'][0]['weather']
        records = [{
            'lat': data_w['lat'],
            'lon': data_w['lon'],
            'date': data_w['data'][0]['dt'],
            'weather_id': w['id'],
            'weather': w['main']
        } for w in weather_list]

        df_w = pd.concat([df_w, pd.DataFrame(records)], ignore_index=True)
    else:
        print("Error:", response.status_code, response.text)

    # Rate limit: wait to avoid >60 calls/min
    time.sleep(SECONDS_BETWEEN_CALLS)

# %%
# # Apply it row-wise

# # df_w['utc_date'] = pd.to_datetime(df_w['date'], unit='s', utc=True)
# # df_w['date'] = pd.to_datetime(df_w['date'], unit='s').dt.date
# df_weather = df_w.copy()
# df_weather['date'] = pd.to_datetime(df_w['date'], unit='s').dt.strftime('%Y-%m-%d')
# df_weather['alert'] = df_weather['weather_id'].apply(lambda x: is_alert(x))
# df_weather = get_city_id(df_weather)

# df_weather['id'] = range(1, len(df_weather)+1)

# df_weather = df_weather.drop(['lat', 'lon'], axis=1)

# # adjusted order
# desired_order = ['id', 'date', 'city_id', 'weather_id', 'weather', 'alert']
# df_weather = df_weather[desired_order]

# df_weather

# %%
# write out
# df_weather.to_csv('data/intermediate/weather_500.csv', index=False)

# %%
filtered_df = df_coord_time[515:]
filtered_df
# Out:
#           lat       lon   timestamp   datetime
# 515   29.7604  -95.3698  1750291200 2025-06-19
# 516   29.7604  -95.3698  1750377600 2025-06-20
# 517   29.7604  -95.3698  1750464000 2025-06-21
# 518   29.7604  -95.3698  1750550400 2025-06-22
# 519   39.7392 -104.9903  1735689600 2025-01-01
# ...       ...       ...         ...        ...
# 1206  38.9072  -77.0369  1750204800 2025-06-18
# 1207  38.9072  -77.0369  1750291200 2025-06-19
# 1208  38.9072  -77.0369  1750377600 2025-06-20
# 1209  38.9072  -77.0369  1750464000 2025-06-21
# 1210  38.9072  -77.0369  1750550400 2025-06-22
#
# [696 rows x 4 columns]

# %% [markdown]
# # weather api 500:

# %%
# continue the scraping
weather_api = os.getenv('OpenWeatherMap_API')

import time
import requests
import pandas as pd
from requests.exceptions import RequestException, ConnectionError


MAX_CALLS_PER_MINUTE = 60
MAX_TOTAL_CALLS = 1000
SECONDS_BETWEEN_CALLS = 60 / MAX_CALLS_PER_MINUTE  # 1.0 seconds

total_calls = 0
start_time = time.time()
df_w = pd.DataFrame()  # Initialize your result dataframe

try:
    for index, row in df_coord_time[501:514].iterrows():
        if total_calls >= MAX_TOTAL_CALLS:
            print("Reached total API call limit (1000).")
            break

        lat = row['lat']
        lon = row['lon']
        timestamp = row['timestamp']
        url = f"https://api.openweathermap.org/data/3.0/onecall/timemachine?lat={lat}&lon={lon}&dt={timestamp}&appid={weather_api}"

        try:
            response = requests.get(url, timeout=10)
            total_calls += 1

            if response.status_code == 200:
                data_w = response.json()
                print(index, data_w)

                weather_list = data_w['data'][0]['weather']
                records = [{
                    'lat': data_w['lat'],
                    'lon': data_w['lon'],
                    'date': data_w['data'][0]['dt'],
                    'weather_id': w['id'],
                    'weather': w['main']
                } for w in weather_list]

                df_w = pd.concat([df_w, pd.DataFrame(records)], ignore_index=True)

            else:
                print("Error:", response.status_code, response.text)

            time.sleep(SECONDS_BETWEEN_CALLS)

        except (ConnectionError, RequestException) as e:
            print(f"⚠️ Request failed at index {index}: {e}")
            break

except Exception as e:
    print(f"🚨 Fatal error during loop: {e}")
# Out:
# 501 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 1749081600, 'sunrise': 1749036060, 'sunset': 1749086343, 'temp': 300.57, 'feels_like': 304.98, 'pressure': 1012, 'humidity': 89, 'dew_point': 298.59, 'clouds': 63, 'wind_speed': 2.24, 'wind_deg': 106, 'wind_gust': 4.92, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'rain': {'1h': 3.56}}]}
# 502 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 1749168000, 'sunrise': 1749122451, 'sunset': 1749172772, 'temp': 304.66, 'feels_like': 311.66, 'pressure': 1013, 'humidity': 71, 'dew_point': 298.76, 'clouds': 40, 'visibility': 10000, 'wind_speed': 5.66, 'wind_deg': 180, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]}]}
# 503 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 1749254400, 'sunrise': 1749208844, 'sunset': 1749259200, 'temp': 305.04, 'feels_like': 312.04, 'pressure': 1013, 'humidity': 69, 'dew_point': 298.64, 'clouds': 0, 'visibility': 10000, 'wind_speed': 8.23, 'wind_deg': 150, 'wind_gust': 11.83, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]}]}
# 504 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 1749340800, 'sunrise': 1749295239, 'sunset': 1749345627, 'temp': 305.39, 'feels_like': 312.11, 'pressure': 1012, 'humidity': 64, 'dew_point': 297.71, 'clouds': 20, 'visibility': 10000, 'wind_speed': 7.2, 'wind_deg': 160, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]}]}
# 505 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 1749427200, 'sunrise': 1749381634, 'sunset': 1749432053, 'temp': 305.56, 'feels_like': 312.56, 'pressure': 1010, 'humidity': 67, 'dew_point': 298.64, 'clouds': 40, 'visibility': 10000, 'wind_speed': 7.72, 'wind_deg': 180, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]}]}
# 506 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 1749513600, 'sunrise': 1749468031, 'sunset': 1749518478, 'temp': 304.4, 'feels_like': 311.4, 'pressure': 1010, 'humidity': 71, 'dew_point': 298.51, 'clouds': 20, 'visibility': 10000, 'wind_speed': 6.17, 'wind_deg': 170, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'rain': {'1h': 0.25}}]}
# 507 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 1749600000, 'sunrise': 1749554430, 'sunset': 1749604903, 'temp': 303.58, 'feels_like': 310.08, 'pressure': 1012, 'humidity': 73, 'dew_point': 298.19, 'clouds': 75, 'visibility': 10000, 'wind_speed': 5.66, 'wind_deg': 110, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]}]}
# 508 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 1749686400, 'sunrise': 1749640829, 'sunset': 1749691326, 'temp': 300.65, 'feels_like': 304.28, 'pressure': 1013, 'humidity': 82, 'dew_point': 297.3, 'clouds': 20, 'visibility': 10000, 'wind_speed': 3.6, 'wind_deg': 70, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]}]}
# 509 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 1749772800, 'sunrise': 1749727230, 'sunset': 1749777748, 'temp': 299.09, 'feels_like': 299.8, 'pressure': 1011, 'humidity': 79, 'dew_point': 295.17, 'clouds': 0, 'visibility': 10000, 'wind_speed': 5.14, 'wind_deg': 130, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]}]}
# 510 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 1749859200, 'sunrise': 1749813632, 'sunset': 1749864170, 'temp': 304.05, 'feels_like': 311.05, 'pressure': 1012, 'humidity': 72, 'dew_point': 298.41, 'clouds': 0, 'visibility': 10000, 'wind_speed': 6.69, 'wind_deg': 140, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]}]}
# 511 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 1749945600, 'sunrise': 1749900036, 'sunset': 1749950590, 'temp': 303.3, 'feels_like': 309.86, 'pressure': 1015, 'humidity': 75, 'dew_point': 298.38, 'clouds': 75, 'visibility': 10000, 'wind_speed': 3.09, 'wind_deg': 190, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]}]}
# 512 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 1750032000, 'sunrise': 1749986441, 'sunset': 1750037010, 'temp': 296.19, 'feels_like': 296.95, 'pressure': 1015, 'humidity': 92, 'dew_point': 294.82, 'clouds': 100, 'visibility': 8047, 'wind_speed': 13.89, 'wind_deg': 330, 'wind_gust': 20.06, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}]}
# 513 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 1750118400, 'sunrise': 1750072846, 'sunset': 1750123428, 'temp': 300.5, 'feels_like': 303.24, 'pressure': 1014, 'humidity': 76, 'dew_point': 295.9, 'clouds': 53, 'wind_speed': 1.34, 'wind_deg': 255, 'wind_gust': 4.92, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]}]}

# %%
# continue the scraping
weather_api = os.getenv('OpenWeatherMap_API')

import time
import requests
import pandas as pd
from requests.exceptions import RequestException, ConnectionError


MAX_CALLS_PER_MINUTE = 60
MAX_TOTAL_CALLS = 1000
SECONDS_BETWEEN_CALLS = 60 / MAX_CALLS_PER_MINUTE  # 1.0 seconds

total_calls = 0
start_time = time.time()
df_w = pd.DataFrame()  # Initialize your result dataframe

try:
    for index, row in df_coord_time[515:].iterrows():
        if total_calls >= MAX_TOTAL_CALLS:
            print("Reached total API call limit (1000).")
            break

        lat = row['lat']
        lon = row['lon']
        timestamp = row['timestamp']
        url = f"https://api.openweathermap.org/data/3.0/onecall/timemachine?lat={lat}&lon={lon}&dt={timestamp}&appid={weather_api}"

        try:
            response = requests.get(url, timeout=10)
            total_calls += 1

            if response.status_code == 200:
                data_w = response.json()
                print(index, data_w)

                weather_list = data_w['data'][0]['weather']
                records = [{
                    'lat': data_w['lat'],
                    'lon': data_w['lon'],
                    'date': data_w['data'][0]['dt'],
                    'weather_id': w['id'],
                    'weather': w['main']
                } for w in weather_list]

                df_w = pd.concat([df_w, pd.DataFrame(records)], ignore_index=True)

            else:
                print("Error:", response.status_code, response.text)

            time.sleep(SECONDS_BETWEEN_CALLS)

        except (ConnectionError, RequestException) as e:
            print(f"⚠️ Request failed at index {index}: {e}")
            break

except Exception as e:
    print(f"🚨 Fatal error during loop: {e}")
# Out:
# 515 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 1750291200, 'sunrise': 1750245662, 'sunset': 1750296261, 'temp': 304.83, 'feels_like': 311.63, 'pressure': 1012, 'humidity': 67, 'dew_point': 297.95, 'uvi': 0.54, 'clouds': 0, 'visibility': 10000, 'wind_speed': 10.29, 'wind_deg': 180, 'wind_gust': 13.38, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}]}]}
# 516 {'lat': 29.7604, 'lon': -95.3698, 'timezone': 'America/Chicago', 'timezone_offset': -18000, 'data': [{'dt': 
{'lat': 38.9072, 'lon': -77.0369, 'timezone': 'America/New_York', 'timezone_offset': -14400, 'data': [{'dt': 1749859200, 'sunrise': 1749807737, 'sunset': 1749861264, 'temp': 299.27, 'feels_like': 299.27, 'pressure': 1016, 'humidity': 67, 'dew_point': 292.66, 'clouds': 75, 'visibility': 10000, 'wind_speed': 2.68, 'wind_deg': 88, 'wind_gust': 3.58, 'weather': [{'id': 211, 'main': 'Thunderstorm', 'description': 'thunderstorm', 'icon': '11d'}]}]}
# 1203 {'lat': 38.9072, 'lon': -77.0369, 'timezone': 'America/New_York', 'timezone_offset': -14400, 'data': [{'dt': 1749945600, 'sunrise': 1749894137, 'sunset': 1749947688, 'temp': 296.14, 'feels_like': 296.58, 'pressure': 1016, 'humidity': 80, 'dew_point': 292.51, 'clouds': 100, 'wind_speed': 0.45, 'wind_deg': 53, 'wind_gust': 4.47, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'rain': {'3h': 1}}]}
# 1204 {'lat': 38.9072, 'lon': -77.0369, 'timezone': 'America/New_York', 'timezone_offset': -14400, 'data': [{'dt': 1750032000, 'sunrise': 1749980538, 'sunset': 1750034111, 'temp': 292.28, 'feels_like': 292.68, 'pressure': 1018, 'humidity': 93, 'dew_point': 291.12, 'clouds': 100, 'visibility': 6437, 'wind_speed': 3.6, 'wind_deg': 60, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'rain': {'1h': 3.05}}]}
# 1205 {'lat': 38.9072, 'lon': -77.0369, 'timezone': 'America/New_York', 'timezone_offset': -14400, 'data': [{'dt': 1750118400, 'sunrise': 1750066941, 'sunset': 1750120532, 'temp': 292.24, 'feels_like': 292.71, 'pressure': 1017, 'humidity': 96, 'dew_point': 291.59, 'clouds': 99, 'wind_speed': 0.45, 'wind_deg': 66, 'wind_gust': 0.89, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'rain': {'1h': 0.38}}]}
# 1206 {'lat': 38.9072, 'lon': -77.0369, 'timezone': 'America/New_York', 'timezone_offset': -14400, 'data': [{'dt': 1750204800, 'sunrise': 1750153346, 'sunset': 1750206952, 'temp': 298.67, 'feels_like': 299.6, 'pressure': 1012, 'humidity': 89, 'dew_point': 296.72, 'uvi': 0.11, 'clouds': 75, 'visibility': 10000, 'wind_speed': 3.09, 'wind_deg': 150, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]}]}
# 1207 {'lat': 38.9072, 'lon': -77.0369, 'timezone': 'America/New_York', 'timezone_offset': -14400, 'data': [{'dt': 1750291200, 'sunrise': 1750239752, 'sunset': 1750293370, 'temp': 298.75, 'feels_like': 299.82, 'pressure': 1010, 'humidity': 94, 'dew_point': 297.71, 'uvi': 0.09, 'clouds': 75, 'visibility': 10000, 'wind_speed': 0.89, 'wind_deg': 261, 'wind_gust': 0.89, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]}]}
# 1208 {'lat': 38.9072, 'lon': -77.0369, 'timezone': 'America/New_York', 'timezone_offset': -14400, 'data': [{'dt': 1750377600, 'sunrise': 1750326161, 'sunset': 1750379786, 'temp': 296.29, 'feels_like': 297.06, 'pressure': 1007, 'humidity': 92, 'dew_point': 294.92, 'uvi': 0.08, 'clouds': 100, 'visibility': 10000, 'wind_speed': 3.09, 'wind_deg': 170, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}]}
# 1209 {'lat': 38.9072, 'lon': -77.0369, 'timezone': 'America/New_York', 'timezone_offset': -14400, 'data': [{'dt': 1750464000, 'sunrise': 1750412571, 'sunset': 1750466200, 'temp': 300.14, 'feels_like': 301.67, 'pressure': 1015, 'humidity': 66, 'dew_point': 293.25, 'uvi': 0.06, 'clouds': 75, 'visibility': 10000, 'wind_speed': 3.09, 'wind_deg': 200, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]}]}
# 1210 {'lat': 38.9072, 'lon': -77.0369, 'timezone': 'America/New_York', 'timezone_offset': -14400, 'data': [{'dt': 1750550400, 'sunrise': 1750498983, 'sunset': 1750552613, 'temp': 301.9, 'feels_like': 304.36, 'pressure': 1014, 'humidity': 64, 'dew_point': 294.41, 'uvi': 0.11, 'clouds': 75, 'visibility': 10000, 'wind_speed': 4.12, 'wind_deg': 180, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}]}]}

# %%
# Apply it row-wise

# df_w['utc_date'] = pd.to_datetime(df_w['date'], unit='s', utc=True)
# df_w['date'] = pd.to_datetime(df_w['date'], unit='s').dt.date
df_weather = df_w.copy()
df_weather['date'] = pd.to_datetime(df_w['date'], unit='s').dt.strftime('%Y-%m-%d')
df_weather['alert'] = df_weather['weather_id'].apply(lambda x: is_alert(x))
df_weather = get_city_id(df_weather)

df_weather['id'] = range(1, len(df_weather)+1)

df_weather = df_weather.drop(['lat', 'lon'], axis=1)

# adjusted order
desired_order = ['id', 'date', 'city_id', 'weather_id', 'weather', 'alert']
df_weather = df_weather[desired_order]

df_weather
# Out:
#     id        date  city_id  weather_id weather  alert
# 0    1  2025-06-05        3         501    Rain  False
# 1    2  2025-06-06        3         802  Clouds  False
# 2    3  2025-06-07        3         800   Clear  False
# 3    4  2025-06-08        3         801  Clouds  False
# 4    5  2025-06-09        3         802  Clouds  False
# 5    6  2025-06-10        3         500    Rain  False
# 6    7  2025-06-11        3         803  Clouds  False
# 7    8  2025-06-12        3         801  Clouds  False
# 8    9  2025-06-13        3         800   Clear  False
# 9   10  2025-06-14        3         800   Clear  False
# 10  11  2025-06-15        3         803  Clouds  False
# 11  12  2025-06-16        3         804  Clouds  False
# 12  13  2025-06-17        3         803  Clouds  False

# %%
weather_500 = pd.read_csv('data/intermediate/weather.csv')
weather_500 = weather_500.iloc[:, 1:]

# %%
df_weather_all = pd.concat([weather_500, df_weather])
df_weather_all
# Out:
#     id        date  city_id  weather_id weather  alert
# 0    1  2025-01-01        1         804  Clouds  False
# 1    2  2025-01-02        1         800   Clear  False
# 2    3  2025-01-03        1         800   Clear  False
# 3    4  2025-01-04        1         800   Clear  False
# 4    5  2025-01-05        1         804  Clouds  False
# ..  ..         ...      ...         ...     ...    ...
# 8    9  2025-06-13        3         800   Clear  False
# 9   10  2025-06-14        3         800   Clear  False
# 10  11  2025-06-15        3         803  Clouds  False
# 11  12  2025-06-16        3         804  Clouds  False
# 12  13  2025-06-17        3         803  Clouds  False
#
# [1233 rows x 6 columns]

# %%
df_weather_all.to_csv('data/intermediate/weather.csv', index=False)

# %%
# from geopy.geocoders import Nominatim

# def get_city_name(lat, lon):
#     geolocator = Nominatim(user_agent="weather_alert_app")
#     location = geolocator.reverse((lat, lon), language="en")
#     if location and 'address' in location.raw:
#         address = location.raw['address']
#         # return address.get('city') or address.get('town') or address.get('village') or address.get('state')
#         return address.get('city')
#     return None

# # Example usage:
# city = get_city_name(39.099724, -94.578331)  # Washington, DC
# print(city)

# %%
# Extracting relevant data

# weather_list = data_w['data'][0]['weather']

# # Build a list of records for each weather condition
# records = [{'lat': data_w['lat'], 'lon': data_w['lon'], 'date': data_w['data'][0]['dt'], 'weather_id': w['id'], 'weather': w['main']} for w in weather_list]

# # Convert to DataFrame
# df_w = pd.DataFrame(records)
# print(df_w)

# %% [markdown]
# ### national holidays

# %%
# cal_api = os.getenv('Calendarific_API')
# url = f"https://calendarific.com/api/v2/holidays?api_key={cal_api}&country=US&year=2025"

# response = requests.get(url)

# if response.status_code == 200:
#     data_h = response.json()
#     # print("Current temperature:", data['current']['temp'])
#     print(data_h)
# else:
#     print("Error:", response.status_code, response.text)

# %%
# df_holiday = pd.DataFrame(data_h['response']['holidays'])
# df_holiday

# %%
# for ptype in df_holiday['primary_type'].unique():
#     print(f"\n--- {ptype} ---")
#     print(df_holiday[df_holiday['primary_type'] == ptype]['name'].unique())

# %%
# df_holiday = df_holiday[df_holiday['primary_type'].isin(['Federal Holiday', 'State Holiday'])][['name', 'locations']]
# df_holiday = df_holiday[df_holiday['primary_type'].isin(['Federal Holiday', 'State Holiday'])][['name', 'locations']]

# %%
# # Example: merging 'locations' column by 'name' using newline separator
# merged = df_holiday.groupby('name', as_index=False).agg({
#     'locations': lambda x: '\\'.join(str(v) for v in x)
#     # For non-text columns you might want to keep the first or max, etc.
#     # 'date': 'first',  # Or 'min', 'max', etc., depending on your goal
# })

# merged

# %%
# def keep_all_location(group):
#     if 'All' in group['locations'].values:
#         return group[group['locations'] == 'All']
#     else:
#         return group

# result = df_holiday.groupby('name', group_keys=False).apply(keep_all_location)
# result

# %%
# # data placeholder
# df_holidays = pd.DataFrame()

# # get 23-25 holiday data
# for year in [2023, 2024, 2025]:
#     us_holidays = holidays.UnitedStates(years=year)
#     df_holidays = pd.concat([df_holidays, pd.DataFrame(list(us_holidays.items()), columns=['date', 'name'])], ignore_index=True)

# # add id column
# df_holidays['id'] = range(1, len(df_holidays)+1)
# df_holidays['date'] = pd.to_datetime(df_holidays['date'], errors='coerce')

# # adjust order
# desired_order = ['id', 'name', 'date']
# df_holidays = df_holidays[desired_order]
# df_holidays['state'] = 'placeholder'

# df_holidays

# %% [markdown]
# ## airport

# %%
# price_api = os.getenv('AMADEUS_API_KEY')
# price_secret = os.getenv('AMADEUS_SECRET')

# amadeus = Client(
#     client_id=price_api,
#     client_secret=price_secret
# )



# # city - airport
# iata_results = []


# for city, (lat, lon) in city_coords.items():
#     try:
#         response = amadeus.reference_data.locations.airports.get(latitude=lat, longitude=lon)
#         if response.data:
#             nearest = response.data[0]
#             iata_results.append({
#                 "iata_code": nearest["iataCode"]
#             })
#     except Exception as e:
#         print(f"Failed for {city}: {e}")

# # Convert to DataFrame
# df_iata = pd.DataFrame(iata_results)
# df_iata['city_id'] = range(1, len(df_iata)+1)
# df_iata['id'] = range(1, len(df_iata)+1)
# desired_order = ['id', 'iata_code', 'city_id']
# df_iata = df_iata[desired_order]

# print(df_iata)
# Out:
#    id iata_code  city_id
# 0   1       LAX        1
# 1   2       ORD        2
# 2   3       IAH        3
# 3   4       DEN        4
# 4   5       EWR        5
# 5   6       SFO        6
# 6   7       DCA        7

# %%
# encode dc airport to united hub
# df_iata.loc[6, 'iata_code'] = 'IAD'
# df_iata.to_csv('data/intermediate/city_airport.csv', index=False)
df_iata = pd.read_csv('data/intermediate/city_airport.csv')
df_iata
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[146], line 4
#       1 # encode dc airport to united hub
#       2 # df_iata.loc[6, 'iata_code'] = 'IAD'
#       3 # df_iata.to_csv('data/intermediate/city_airport.csv')
# ----> 4 df_iata = pd.read_csv('data/intermediate/city_airport.csv', index=False)
#       5 df_iata
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %% [markdown]
# ## route

# %%
from itertools import permutations

# Generate all ordered pairs (departure ≠ destination)
routes = list(permutations(df_iata["id"], 2))

# Convert to DataFrame
routes_df = pd.DataFrame(routes, columns=["depar_airport_id", "desti_airport_id"])

# Optional: Add a unique route_id (if you'll insert into SQL table)
routes_df["id"] = range(1, len(routes_df) + 1)
desired_order = ['id', "depar_airport_id", "desti_airport_id"]
routes_df = routes_df[desired_order]

routes_df
# Out:
#     id  depar_airport_id  desti_airport_id
# 0    1                 1                 2
# 1    2                 1                 3
# 2    3                 1                 4
# 3    4                 1                 5
# 4    5                 1                 6
# 5    6                 1                 7
# 6    7                 2                 1
# 7    8                 2                 3
# 8    9                 2                 4
# 9   10                 2                 5
# 10  11                 2                 6
# 11  12                 2                 7
# 12  13                 3                 1
# 13  14                 3                 2
# 14  15                 3                 4
# 15  16                 3                 5
# 16  17                 3                 6
# 17  18                 3                 7
# 18  19                 4                 1
# 19  20                 4                 2
# 20  21                 4                 3
# 21  22                 4                 5
# 22  23                 4                 6
# 23  24                 4                 7
# 24  25                 5                 1
# 25  26                 5                 2
# 26  27                 5                 3
# 27  28                 5                 4
# 28  29                 5                 6
# 29  30                 5                 7
# 30  31                 6                 1
# 31  32                 6                 2
# 32  33                 6                 3
# 33  34                 6                 4
# 34  35                 6                 5
# 35  36                 6                 7
# 36  37                 7                 1
# 37  38                 7                 2
# 38  39                 7                 3
# 39  40                 7                 4
# 40  41                 7                 5
# 41  42                 7                 6

# %%
routes_df.to_csv('data/intermediate/routes.csv', index=False)

# %% [markdown]
# ## flight

# %%
# !pip install amadeus

# %%
def airport_to_route(df):
    # Create mapping from IATA to airport ID
    iata_to_id = df_iata.set_index('iata_code')['id'].to_dict()

    # Map airport IDs to flights
    df['depar_airport_id'] = df['origin'].map(iata_to_id)
    df['arrival_airport_id'] = df['destination'].map(iata_to_id)

    # Create route lookup: {(depart_id, arrive_id): route_id}
    route_lookup = {
        (row['depar_airport_id'], row['desti_airport_id']): row['id']
        for _, row in routes_df.iterrows()
    }

    # Apply to get route_id
    df['route_id'] = df.apply(
        lambda row: route_lookup.get((row['depar_airport_id'], row['arrival_airport_id'])),
        axis=1
    )
    print(df)
    return(df)

# %%
# historical price trial
# from amadeus import Client, ResponseError

# price_api = os.getenv('AMADEUS_API_KEY')
# price_secret = os.getenv('AMADEUS_SECRET')

# amadeus = Client(
#     client_id=price_api,
#     client_secret=price_secret
# )

# try: 
#     response = amadeus.analytics.itinerary_price_metrics.get(originIataCode='ORD', destinationIataCode='EWR',
#                                             departureDate='2025-05-01')
# except ResponseError as error:
#     print(error)

# response.data
# Out:
# []

# %%
airport_route = pd.DataFrame(list(permutations(df_iata["iata_code"], 2)))
# airport_route

dates = pd.date_range(start="2025-01-01", end="2025-06-30", freq="M", tz="UTC")
df_dates = pd.DataFrame(dates)

route_dates = airport_route.merge(df_dates, how="cross")
route_dates.columns = ['departure_iata', 'arrival_iata', 'departure_date']
route_dates['departure_date'] = pd.to_datetime(route_dates['departure_date']).dt.strftime('%Y-%m-%d')
route_dates['id'] = range(1, len(route_dates)+1)

route_dates
# Out:
# /var/folders/x7/k10zkcs917x1mtwm_l5s0z5c0000gn/T/ipykernel_66000/736925844.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(start="2025-01-01", end="2025-06-30", freq="M", tz="UTC")
#     departure_iata arrival_iata departure_date   id
# 0              LAX          ORD     2025-01-31    1
# 1              LAX          ORD     2025-02-28    2
# 2              LAX          ORD     2025-03-31    3
# 3              LAX          ORD     2025-04-30    4
# 4              LAX          ORD     2025-05-31    5
# ..             ...          ...            ...  ...
# 247            IAD          SFO     2025-02-28  248
# 248            IAD          SFO     2025-03-31  249
# 249            IAD          SFO     2025-04-30  250
# 250            IAD          SFO     2025-05-31  251
# 251            IAD          SFO     2025-06-30  252
#
# [252 rows x 4 columns]

# %%
from amadeus import Client, ResponseError

price_api = os.getenv('AMADEUS_API_KEY')
price_secret = os.getenv('AMADEUS_SECRET')

amadeus = Client(
    client_id=price_api,
    client_secret=price_secret
)
# Quartile label mapping
quartile_map = {
    "MINIMUM": "price_quantile_minimum",
    "FIRST": "price_quantile_low",
    "MEDIUM": "price_quantile_middle",
    "THIRD": "price_quantile_high",
    "MAXIMUM": "price_quantile_maximum"
}

MAX_CALLS_PER_MIN = 20
SECONDS_BETWEEN_CALLS = 60 / MAX_CALLS_PER_MIN  # 3 seconds
MAX_TOTAL_CALLS = 2000

response_data = []
call_count = 0

for index, route in route_dates.iterrows():
    if call_count >= MAX_TOTAL_CALLS:
        print("Reached monthly API call limit (2000). Stopping.")
        break

    departure_iata = route['departure_iata']
    arrival_iata = route['arrival_iata']
    departure_date = route['departure_date']

    try: 
        response = amadeus.analytics.itinerary_price_metrics.get(
            originIataCode=departure_iata, 
            destinationIataCode=arrival_iata,
            departureDate=departure_date,
            currencyCode="USD"
        )

        call_count += 1

        if response.data:
            response_data.append(response.data[0])
            print(index, response.data[0])
        else:
            print(f'No data for {departure_iata} to {arrival_iata} on {departure_date}')

        # Respect per-minute rate limit
        time.sleep(SECONDS_BETWEEN_CALLS)

    except ResponseError as error:
        if hasattr(error, 'response') and error.response.status_code == 429:
            retry_after = int(error.response.headers.get("Retry-After", 60))
            print(f"429 Rate Limit hit. Retrying after {retry_after} seconds.")
            time.sleep(retry_after)
        else:
            print(f"Error for {departure_iata} to {arrival_iata} on {departure_date}. ")

# Build DataFrame from response_data
rows = []
for item in response_data:
    row = {
        "origin": item['origin']['iataCode'],
        "destination": item['destination']['iataCode'],
        "departure_date": item['departureDate']
    }
    for metric in item['priceMetrics']:
        key = quartile_map.get(metric['quartileRanking'])
        row[key] = float(metric['amount'])
        
    rows.append(row)

df_f = pd.DataFrame(rows)
print(df_f)
# Out:
# 0 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '45.06', 'quartileRanking': 'MINIMUM'}, {'amount': '225.63', 'quartileRanking': 'FIRST'}, {'amount': '323.14', 'quartileRanking': 'MEDIUM'}, {'amount': '417.43', 'quartileRanking': 'THIRD'}, {'amount': '590.70', 'quartileRanking': 'MAXIMUM'}]}
# 1 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '45.06', 'quartileRanking': 'MINIMUM'}, {'amount': '231.31', 'quartileRanking': 'FIRST'}, {'amount': '327.49', 'quartileRanking': 'MEDIUM'}, {'amount': '428.40', 'quartileRanking': 'THIRD'}, {'amount': '588.68', 'quartileRanking': 'MAXIMUM'}]}
# 2 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '45.06', 'quartileRanking': 'MINIMUM'}, {'amount': '241.29', 'quartileRanking': 'FIRST'}, {'amount': '342.78', 'quartileRanking': 'MEDIUM'}, {'amount': '434.55', 'quartileRanking': 'THIRD'}, {'amount': '595.02', 'quartileRanking': 'MAXIMUM'}]}
# 3 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '45.50', 'quartileRanking': 'MINIMUM'}, {'amount': '268.53', 'quartileRanking': 'FIRST'}, {'amount': '364.22', 'quartileRanking': 'MEDIUM'}, {'amount': '491.29', 'quartileRanking': 'THIRD'}, {'amount': '602.88', 'quartileRanking': 'MAXIMUM'}]}
# 4 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '45.48', 'quartileRanking': 'MINIMUM'}, {'amount': '269.15', 'quartileRanking': 'FIRST'}, {'amount': '366.57', 'quartileRanking': 'MEDIUM'}, {'amount': '494.52', 'quartileRanking': 'THIRD'}, {'amount': '603.35', 'quartileRanking': 'MAXIMUM'}]}
# 5 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '46.21', 'quartileRanking': 'MINIMUM'}, {'amount': '265.54', 'quartileRanking': 'FIRST'}, {'amount': '364.55', 'quartileRanking': 'MEDIUM'}, {'amount': '482.43', 'quartileRanking': 'THIRD'}, {'amount': '604.17', 'quartileRanking': 'MAXIMUM'}]}
# 6 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'IAH'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '42.61', 'quartileRanking': 'MINIMUM'}, {'amount': '237.46', 'quartileRanking': 'FIRST'}, {'amount': '252.88', 'quartileRanking': 'MEDIUM'}, {'amount': '313.29', 'quartileRanking': 'THIRD'}, {'amount': '401.65', 'quartileRanking': 'MAXIMUM'}]}
# 7 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'IAH'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '42.61', 'quartileRanking': 'MINIMUM'}, {'amount': '241.43', 'quartileRanking': 'FIRST'}, {'amount': '260.89', 'quartileRanking': 'MEDIUM'}, {'amount': '316.64', 'quartileRanking': 'THIRD'}, {'amount': '404.17', 'quartileRanking': 'MAXIMUM'}]}
# 8 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'IAH'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '42.61', 'quartileRanking': 'MINIMUM'}, {'amount': '245.85', 'quartileRanking': 'FIRST'}, {'amount': '259.17', 'quartileRanking': 'MEDIUM'}, {'amount': '313.59', 'quartileRanking': 'THIRD'}, {'amount': '409.27', 'quartileRanking': 'MAXIMUM'}]}
# 9 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'IAH'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '43.00', 'quartileRanking': 'MINIMUM'}, {'amount': '258.07', 'quartileRanking': 'FIRST'}, {'amount': '279.94', 'quartileRanking': 'MEDIUM'}, {'amount': '374.22', 'quartileRanking': 'THIRD'}, {'amount': '414.54', 'quartileRanking': 'MAXIMUM'}]}
# 10 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'IAH'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '42.98', 'quartileRanking': 'MINIMUM'}, {'amount': '260.15', 'quartileRanking': 'FIRST'}, {'amount': '279.94', 'quartileRanking': 'MEDIUM'}, {'amount': '372.57', 'quartileRanking': 'THIRD'}, {'amount': '419.20', 'quartileRanking': 'MAXIMUM'}]}
# 11 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'IAH'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '43.72', 'quartileRanking': 'MINIMUM'}, {'amount': '243.25', 'quartileRanking': 'FIRST'}, {'amount': '260.59', 'quartileRanking': 'MEDIUM'}, {'amount': '334.44', 'quartileRanking': 'THIRD'}, {'amount': '411.65', 'quartileRanking': 'MAXIMUM'}]}
# 12 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '43.95', 'quartileRanking': 'MINIMUM'}, {'amount': '178.40', 'quartileRanking': 'FIRST'}, {'amount': '246.41', 'quartileRanking': 'MEDIUM'}, {'amount': '268.98', 'quartileRanking': 'THIRD'}, {'amount': '386.03', 'quartileRanking': 'MAXIMUM'}]}
# 13 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '43.95', 'quartileRanking': 'MINIMUM'}, {'amount': '180.87', 'quartileRanking': 'FIRST'}, {'amount': '255.38', 'quartileRanking': 'MEDIUM'}, {'amount': '276.78', 'quartileRanking': 'THIRD'}, {'amount': '397.39', 'quartileRanking': 'MAXIMUM'}]}
# 14 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '43.95', 'quartileRanking': 'MINIMUM'}, {'amount': '190.44', 'quartileRanking': 'FIRST'}, {'amount': '267.70', 'quartileRanking': 'MEDIUM'}, {'amount': '280.50', 'quartileRanking': 'THIRD'}, {'amount': '402.90', 'quartileRanking': 'MAXIMUM'}]}
# 15 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.33', 'quartileRanking': 'MINIMUM'}, {'amount': '197.08', 'quartileRanking': 'FIRST'}, {'amount': '270.41', 'quartileRanking': 'MEDIUM'}, {'amount': '281.82', 'quartileRanking': 'THIRD'}, {'amount': '407.84', 'quartileRanking': 'MAXIMUM'}]}
# 16 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.32', 'quartileRanking': 'MINIMUM'}, {'amount': '199.69', 'quartileRanking': 'FIRST'}, {'amount': '250.40', 'quartileRanking': 'MEDIUM'}, {'amount': '283.79', 'quartileRanking': 'THIRD'}, {'amount': '409.97', 'quartileRanking': 'MAXIMUM'}]}
# 17 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '45.03', 'quartileRanking': 'MINIMUM'}, {'amount': '199.55', 'quartileRanking': 'FIRST'}, {'amount': '229.36', 'quartileRanking': 'MEDIUM'}, {'amount': '287.71', 'quartileRanking': 'THIRD'}, {'amount': '397.71', 'quartileRanking': 'MAXIMUM'}]}
# 18 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'EWR'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '68.75', 'quartileRanking': 'MINIMUM'}, {'amount': '407.13', 'quartileRanking': 'FIRST'}, {'amount': '439.47', 'quartileRanking': 'MEDIUM'}, {'amount': '551.49', 'quartileRanking': 'THIRD'}, {'amount': '648.91', 'quartileRanking': 'MAXIMUM'}]}
# 19 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'EWR'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '68.75', 'quartileRanking': 'MINIMUM'}, {'amount': '410.18', 'quartileRanking': 'FIRST'}, {'amount': '439.49', 'quartileRanking': 'MEDIUM'}, {'amount': '544.58', 'quartileRanking': 'THIRD'}, {'amount': '649.66', 'quartileRanking': 'MAXIMUM'}]}
# 20 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'EWR'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '68.75', 'quartileRanking': 'MINIMUM'}, {'amount': '419.82', 'quartileRanking': 'FIRST'}, {'amount': '454.29', 'quartileRanking': 'MEDIUM'}, {'amount': '552.66', 'quartileRanking': 'THIRD'}, {'amount': '656.21', 'quartileRanking': 'MAXIMUM'}]}
# 21 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'EWR'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '69.35', 'quartileRanking': 'MINIMUM'}, {'amount': '432.89', 'quartileRanking': 'FIRST'}, {'amount': '472.44', 'quartileRanking': 'MEDIUM'}, {'amount': '543.74', 'quartileRanking': 'THIRD'}, {'amount': '662.68', 'quartileRanking': 'MAXIMUM'}]}
# 22 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'EWR'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '69.57', 'quartileRanking': 'MINIMUM'}, {'amount': '424.87', 'quartileRanking': 'FIRST'}, {'amount': '478.27', 'quartileRanking': 'MEDIUM'}, {'amount': '543.92', 'quartileRanking': 'THIRD'}, {'amount': '670.99', 'quartileRanking': 'MAXIMUM'}]}
# 23 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'EWR'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '70.39', 'quartileRanking': 'MINIMUM'}, {'amount': '397.91', 'quartileRanking': 'FIRST'}, {'amount': '488.67', 'quartileRanking': 'MEDIUM'}, {'amount': '584.88', 'quartileRanking': 'THIRD'}, {'amount': '682.50', 'quartileRanking': 'MAXIMUM'}]}
# 24 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '47.73', 'quartileRanking': 'MINIMUM'}, {'amount': '282.01', 'quartileRanking': 'FIRST'}, {'amount': '312.10', 'quartileRanking': 'MEDIUM'}, {'amount': '324.86', 'quartileRanking': 'THIRD'}, {'amount': '363.12', 'quartileRanking': 'MAXIMUM'}]}
# 25 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '47.73', 'quartileRanking': 'MINIMUM'}, {'amount': '288.42', 'quartileRanking': 'FIRST'}, {'amount': '312.13', 'quartileRanking': 'MEDIUM'}, {'amount': '326.56', 'quartileRanking': 'THIRD'}, {'amount': '359.50', 'quartileRanking': 'MAXIMUM'}]}
# 26 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '47.73', 'quartileRanking': 'MINIMUM'}, {'amount': '296.22', 'quartileRanking': 'FIRST'}, {'amount': '318.41', 'quartileRanking': 'MEDIUM'}, {'amount': '328.57', 'quartileRanking': 'THIRD'}, {'amount': '364.26', 'quartileRanking': 'MAXIMUM'}]}
# 27 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '47.99', 'quartileRanking': 'MINIMUM'}, {'amount': '306.81', 'quartileRanking': 'FIRST'}, {'amount': '331.44', 'quartileRanking': 'MEDIUM'}, {'amount': '333.74', 'quartileRanking': 'THIRD'}, {'amount': '370.52', 'quartileRanking': 'MAXIMUM'}]}
# 28 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '47.97', 'quartileRanking': 'MINIMUM'}, {'amount': '300.09', 'quartileRanking': 'FIRST'}, {'amount': '326.12', 'quartileRanking': 'MEDIUM'}, {'amount': '331.62', 'quartileRanking': 'THIRD'}, {'amount': '383.95', 'quartileRanking': 'MAXIMUM'}]}
# 29 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '48.55', 'quartileRanking': 'MINIMUM'}, {'amount': '252.23', 'quartileRanking': 'FIRST'}, {'amount': '300.77', 'quartileRanking': 'MEDIUM'}, {'amount': '321.85', 'quartileRanking': 'THIRD'}, {'amount': '378.59', 'quartileRanking': 'MAXIMUM'}]}
# 30 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'IAD'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '85.77', 'quartileRanking': 'MINIMUM'}, {'amount': '350.33', 'quartileRanking': 'FIRST'}, {'amount': '430.24', 'quartileRanking': 'MEDIUM'}, {'amount': '497.09', 'quartileRanking': 'THIRD'}, {'amount': '702.26', 'quartileRanking': 'MAXIMUM'}]}
# 31 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'IAD'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '85.77', 'quartileRanking': 'MINIMUM'}, {'amount': '339.23', 'quartileRanking': 'FIRST'}, {'amount': '440.44', 'quartileRanking': 'MEDIUM'}, {'amount': '521.48', 'quartileRanking': 'THIRD'}, {'amount': '686.94', 'quartileRanking': 'MAXIMUM'}]}
# 32 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'IAD'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '85.77', 'quartileRanking': 'MINIMUM'}, {'amount': '339.59', 'quartileRanking': 'FIRST'}, {'amount': '466.01', 'quartileRanking': 'MEDIUM'}, {'amount': '563.80', 'quartileRanking': 'THIRD'}, {'amount': '693.91', 'quartileRanking': 'MAXIMUM'}]}
# 33 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'IAD'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '87.02', 'quartileRanking': 'MINIMUM'}, {'amount': '350.22', 'quartileRanking': 'FIRST'}, {'amount': '488.71', 'quartileRanking': 'MEDIUM'}, {'amount': '588.64', 'quartileRanking': 'THIRD'}, {'amount': '704.34', 'quartileRanking': 'MAXIMUM'}]}
# 34 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'LAX'}, 'destination': {'iataCode': 'I
{'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'IAH'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '41.10', 'quartileRanking': 'MINIMUM'}, {'amount': '176.13', 'quartileRanking': 'FIRST'}, {'amount': '214.38', 'quartileRanking': 'MEDIUM'}, {'amount': '348.24', 'quartileRanking': 'THIRD'}, {'amount': '391.95', 'quartileRanking': 'MAXIMUM'}]}
# 45 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'IAH'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '41.30', 'quartileRanking': 'MINIMUM'}, {'amount': '182.63', 'quartileRanking': 'FIRST'}, {'amount': '215.09', 'quartileRanking': 'MEDIUM'}, {'amount': '373.68', 'quartileRanking': 'THIRD'}, {'amount': '395.17', 'quartileRanking': 'MAXIMUM'}]}
# 46 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'IAH'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '41.28', 'quartileRanking': 'MINIMUM'}, {'amount': '182.73', 'quartileRanking': 'FIRST'}, {'amount': '210.90', 'quartileRanking': 'MEDIUM'}, {'amount': '366.40', 'quartileRanking': 'THIRD'}, {'amount': '389.34', 'quartileRanking': 'MAXIMUM'}]}
# 47 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'IAH'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '41.78', 'quartileRanking': 'MINIMUM'}, {'amount': '178.07', 'quartileRanking': 'FIRST'}, {'amount': '207.61', 'quartileRanking': 'MEDIUM'}, {'amount': '313.00', 'quartileRanking': 'THIRD'}, {'amount': '373.59', 'quartileRanking': 'MAXIMUM'}]}
# 48 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.40', 'quartileRanking': 'MINIMUM'}, {'amount': '185.25', 'quartileRanking': 'FIRST'}, {'amount': '225.49', 'quartileRanking': 'MEDIUM'}, {'amount': '324.97', 'quartileRanking': 'THIRD'}, {'amount': '435.35', 'quartileRanking': 'MAXIMUM'}]}
# 49 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.40', 'quartileRanking': 'MINIMUM'}, {'amount': '186.56', 'quartileRanking': 'FIRST'}, {'amount': '229.13', 'quartileRanking': 'MEDIUM'}, {'amount': '328.19', 'quartileRanking': 'THIRD'}, {'amount': '421.97', 'quartileRanking': 'MAXIMUM'}]}
# 50 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.40', 'quartileRanking': 'MINIMUM'}, {'amount': '182.84', 'quartileRanking': 'FIRST'}, {'amount': '237.89', 'quartileRanking': 'MEDIUM'}, {'amount': '322.94', 'quartileRanking': 'THIRD'}, {'amount': '423.14', 'quartileRanking': 'MAXIMUM'}]}
# 51 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.69', 'quartileRanking': 'MINIMUM'}, {'amount': '185.70', 'quartileRanking': 'FIRST'}, {'amount': '239.80', 'quartileRanking': 'MEDIUM'}, {'amount': '355.05', 'quartileRanking': 'THIRD'}, {'amount': '429.99', 'quartileRanking': 'MAXIMUM'}]}
# 52 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.67', 'quartileRanking': 'MINIMUM'}, {'amount': '179.62', 'quartileRanking': 'FIRST'}, {'amount': '234.15', 'quartileRanking': 'MEDIUM'}, {'amount': '344.47', 'quartileRanking': 'THIRD'}, {'amount': '422.64', 'quartileRanking': 'MAXIMUM'}]}
# 53 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '45.08', 'quartileRanking': 'MINIMUM'}, {'amount': '174.88', 'quartileRanking': 'FIRST'}, {'amount': '227.34', 'quartileRanking': 'MEDIUM'}, {'amount': '363.15', 'quartileRanking': 'THIRD'}, {'amount': '424.12', 'quartileRanking': 'MAXIMUM'}]}
# No data for ORD to EWR on 2025-01-31
# No data for ORD to EWR on 2025-02-28
# No data for ORD to EWR on 2025-03-31
# No data for ORD to EWR on 2025-04-30
# No data for ORD to EWR on 2025-05-31
# No data for ORD to EWR on 2025-06-30
# 60 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '70.47', 'quartileRanking': 'MINIMUM'}, {'amount': '394.50', 'quartileRanking': 'FIRST'}, {'amount': '513.82', 'quartileRanking': 'MEDIUM'}, {'amount': '550.96', 'quartileRanking': 'THIRD'}, {'amount': '603.88', 'quartileRanking': 'MAXIMUM'}]}
# 61 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '70.47', 'quartileRanking': 'MINIMUM'}, {'amount': '378.73', 'quartileRanking': 'FIRST'}, {'amount': '514.43', 'quartileRanking': 'MEDIUM'}, {'amount': '550.23', 'quartileRanking': 'THIRD'}, {'amount': '613.72', 'quartileRanking': 'MAXIMUM'}]}
# 62 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '70.47', 'quartileRanking': 'MINIMUM'}, {'amount': '387.14', 'quartileRanking': 'FIRST'}, {'amount': '521.91', 'quartileRanking': 'MEDIUM'}, {'amount': '556.89', 'quartileRanking': 'THIRD'}, {'amount': '616.60', 'quartileRanking': 'MAXIMUM'}]}
# 63 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '71.66', 'quartileRanking': 'MINIMUM'}, {'amount': '392.44', 'quartileRanking': 'FIRST'}, {'amount': '543.89', 'quartileRanking': 'MEDIUM'}, {'amount': '563.14', 'quartileRanking': 'THIRD'}, {'amount': '622.32', 'quartileRanking': 'MAXIMUM'}]}
# 64 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '71.88', 'quartileRanking': 'MINIMUM'}, {'amount': '404.28', 'quartileRanking': 'FIRST'}, {'amount': '540.49', 'quartileRanking': 'MEDIUM'}, {'amount': '556.52', 'quartileRanking': 'THIRD'}, {'amount': '623.34', 'quartileRanking': 'MAXIMUM'}]}
# 65 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'ORD'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '72.62', 'quartileRanking': 'MINIMUM'}, {'amount': '469.62', 'quartileRanking': 'FIRST'}, {'amount': '527.96', 'quartileRanking': 'MEDIUM'}, {'amount': '579.89', 'quartileRanking': 'THIRD'}, {'amount': '644.12', 'quartileRanking': 'MAXIMUM'}]}
# No data for ORD to IAD on 2025-01-31
# No data for ORD to IAD on 2025-02-28
# No data for ORD to IAD on 2025-03-31
# No data for ORD to IAD on 2025-04-30
# No data for ORD to IAD on 2025-05-31
# No data for ORD to IAD on 2025-06-30
# 72 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'IAH'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '43.33', 'quartileRanking': 'MINIMUM'}, {'amount': '218.84', 'quartileRanking': 'FIRST'}, {'amount': '282.83', 'quartileRanking': 'MEDIUM'}, {'amount': '338.15', 'quartileRanking': 'THIRD'}, {'amount': '448.22', 'quartileRanking': 'MAXIMUM'}]}
# 73 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'IAH'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '43.33', 'quartileRanking': 'MINIMUM'}, {'amount': '226.25', 'quartileRanking': 'FIRST'}, {'amount': '297.19', 'quartileRanking': 'MEDIUM'}, {'amount': '345.87', 'quartileRanking': 'THIRD'}, {'amount': '450.55', 'quartileRanking': 'MAXIMUM'}]}
# 74 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'IAH'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '43.33', 'quartileRanking': 'MINIMUM'}, {'amount': '245.04', 'quartileRanking': 'FIRST'}, {'amount': '307.82', 'quartileRanking': 'MEDIUM'}, {'amount': '358.22', 'quartileRanking': 'THIRD'}, {'amount': '455.14', 'quartileRanking': 'MAXIMUM'}]}
# 75 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'IAH'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.05', 'quartileRanking': 'MINIMUM'}, {'amount': '267.07', 'quartileRanking': 'FIRST'}, {'amount': '317.61', 'quartileRanking': 'MEDIUM'}, {'amount': '401.26', 'quartileRanking': 'THIRD'}, {'amount': '460.68', 'quartileRanking': 'MAXIMUM'}]}
# 76 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'IAH'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.03', 'quartileRanking': 'MINIMUM'}, {'amount': '264.31', 'quartileRanking': 'FIRST'}, {'amount': '326.11', 'quartileRanking': 'MEDIUM'}, {'amount': '390.82', 'quartileRanking': 'THIRD'}, {'amount': '470.00', 'quartileRanking': 'MAXIMUM'}]}
# 77 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'IAH'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.41', 'quartileRanking': 'MINIMUM'}, {'amount': '255.39', 'quartileRanking': 'FIRST'}, {'amount': '302.70', 'quartileRanking': 'MEDIUM'}, {'amount': '402.75', 'quartileRanking': 'THIRD'}, {'amount': '480.82', 'quartileRanking': 'MAXIMUM'}]}
# No data for IAH to ORD on 2025-01-31
# No data for IAH to ORD on 2025-02-28
# No data for IAH to ORD on 2025-03-31
# No data for IAH to ORD on 2025-04-30
# No data for IAH to ORD on 2025-05-31
# No data for IAH to ORD on 2025-06-30
# No data for IAH to DEN on 2025-01-31
# No data for IAH to DEN on 2025-02-28
# No data for IAH to DEN on 2025-03-31
# No data for IAH to DEN on 2025-04-30
# No data for IAH to DEN on 2025-05-31
# No data for IAH to DEN on 2025-06-30
# No data for IAH to EWR on 2025-01-31
# No data for IAH to EWR on 2025-02-28
# No data for IAH to EWR on 2025-03-31
# No data for IAH to EWR on 2025-04-30
# No data for IAH to EWR on 2025-05-31
# No data for IAH to EWR on 2025-06-30
# No data for IAH to SFO on 2025-01-31
# No data for IAH to SFO on 2025-02-28
# No data for IAH to SFO on 2025-03-31
# No data for IAH to SFO on 2025-04-30
# No data for IAH to SFO on 2025-05-31
# No data for IAH to SFO on 2025-06-30
# No data for IAH to IAD on 2025-01-31
# No data for IAH to IAD on 2025-02-28
# No data for IAH to IAD on 2025-03-31
# No data for IAH to IAD on 2025-04-30
# No data for IAH to IAD on 2025-05-31
# No data for IAH to IAD on 2025-06-30
# 108 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'DEN'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '42.70', 'quartileRanking': 'MINIMUM'}, {'amount': '197.92', 'quartileRanking': 'FIRST'}, {'amount': '244.32', 'quartileRanking': 'MEDIUM'}, {'amount': '292.24', 'quartileRanking': 'THIRD'}, {'amount': '377.43', 'quartileRanking': 'MAXIMUM'}]}
# 109 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'DEN'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '42.70', 'quartileRanking': 'MINIMUM'}, {'amount': '203.72', 'quartileRanking': 'FIRST'}, {'amount': '260.12', 'quartileRanking': 'MEDIUM'}, {'amount': '299.77', 'quartileRanking': 'THIRD'}, {'amount': '377.76', 'quartileRanking': 'MAXIMUM'}]}
# 110 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'DEN'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '42.70', 'quartileRanking': 'MINIMUM'}, {'amount': '218.38', 'quartileRanking': 'FIRST'}, {'amount': '277.50', 'quartileRanking': 'MEDIUM'}, {'amount': '302.75', 'quartileRanking': 'THIRD'}, {'amount': '384.86', 'quartileRanking': 'MAXIMUM'}]}
# 111 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'DEN'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '43.50', 'quartileRanking': 'MINIMUM'}, {'amount': '237.95', 'quartileRanking': 'FIRST'}, {'amount': '280.65', 'quartileRanking': 'MEDIUM'}, {'amount': '315.36', 'quartileRanking': 'THIRD'}, {'amount': '387.01', 'quartileRanking': 'MAXIMUM'}]}
# 112 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'DEN'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '43.48', 'quartileRanking': 'MINIMUM'}, {'amount': '236.26', 'quartileRanking': 'FIRST'}, {'amount': '280.64', 'quartileRanking': 'MEDIUM'}, {'amount': '308.87', 'quartileRanking': 'THIRD'}, {'amount': '388.53', 'quartileRanking': 'MAXIMUM'}]}
# 113 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'DEN'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '43.62', 'quartileRanking': 'MINIMUM'}, {'amount': '226.27', 'quartileRanking': 'FIRST'}, {'amount': '231.67', 'quartileRanking': 'MEDIUM'}, {'amount': '321.36', 'quartileRanking': 'THIRD'}, {'amount': '375.59', 'quartileRanking': 'MAXIMUM'}]}
# 114 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'DEN'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '74.62', 'quartileRanking': 'MINIMUM'}, {'amount': '224.97', 'quartileRanking': 'FIRST'}, {'amount': '301.43', 'quartileRanking': 'MEDIUM'}, {'amount': '334.36', 'quartileRanking': 'THIRD'}, {'amount': '437.97', 'quartileRanking': 'MAXIMUM'}]}
# 115 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'DEN'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '74.62', 'quartileRanking': 'MINIMUM'}, {'amount': '218.23', 'quartileRanking': 'FIRST'}, {'amount': '298.71', 'quartileRanking': 'MEDIUM'}, {'amount': '335.15', 'quartileRanking': 'THIRD'}, {'amount': '438.94', 'quartileRanking': 'MAXIMUM'}]}
# 116 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'DEN'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '74.62', 'quartileRanking': 'MINIMUM'}, {'amount': '225.87', 'quartileRanking': 'FIRST'}, {'amount': '307.16', 'quartileRanking': 'MEDIUM'}, {'amount': '339.16', 'quartileRanking': 'THIRD'}, {'amount': '442.85', 'quartileRanking': 'MAXIMUM'}]}
# 117 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'DEN'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '74.83', 'quartileRanking': 'MINIMUM'}, {'amount': '219.11', 'quartileRanking': 'FIRST'}, {'amount': '309.22', 'quartileRanking': 'MEDIUM'}, {'amount': '363.26', 'quartileRanking': 'THIRD'}, {'amount': '445.24', 'quartileRanking': 'MAXIMUM'}]}
# 118 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'DEN'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '75.38', 'quartileRanking': 'MINIMUM'}, {'amount': '214.74', 'quartileRanking': 'FIRST'}, {'amount': '308.95', 'quartileRanking': 'MEDIUM'}, {'amount': '354.55', 'quartileRanking': 'THIRD'}, {'amount': '440.06', 'quartileRanking': 'MAXIMUM'}]}
# 119 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'DEN'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '76.24', 'quartileRanking': 'MINIMUM'}, {'amount': '213.84', 'quartileRanking': 'FIRST'}, {'amount': '290.32', 'quartileRanking': 'MEDIUM'}, {'amount': '333.14', 'quartileRanking': 'THIRD'}, {'amount': '441.33', 'quartileRanking': 'MAXIMUM'}]}
# No data for DEN to IAH on 2025-01-31
# No data for DEN to IAH on 2025-02-28
# No data for DEN to IAH on 2025-03-31
# No data for DEN to IAH on 2025-04-30
# No data for DEN to IAH on 2025-05-31
# No data for DEN to IAH on 2025-06-30
# No data for DEN to EWR on 2025-01-31
# No data for DEN to EWR on 2025-02-28
# No data for DEN to EWR on 2025-03-31
# No data for DEN to EWR on 2025-04-30
# No data for DEN to EWR on 2025-05-31
# No data for DEN to EWR on 2025-06-30
# No data for DEN to SFO on 2025-01-31
# No data for DEN to SFO on 2025-02-28
# No data for DEN to SFO on 2025-03-31
# No data for DEN to SFO on 2025-04-30
# No data for DEN to SFO on 2025-05-31
# No data for DEN to SFO on 2025-06-30
# No data for DEN to IAD on 2025-01-31
# No data for DEN to IAD on 2025-02-28
# No data for DEN to IAD on 2025-03-31
# No data for DEN to IAD on 2025-04-30
# No data for DEN to IAD on 2025-05-31
# No data for DEN to IAD on 2025-06-30
# 144 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '74.99', 'quartileRanking': 'MINIMUM'}, {'amount': '426.94', 'quartileRanking': 'FIRST'}, {'amount': '444.33', 'quartileRanking': 'MEDIUM'}, {'amount': '579.56', 'quartileRanking': 'THIRD'}, {'amount': '690.58', 'quartileRanking': 'MAXIMUM'}]}
# 145 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '74.99', 'quartileRanking': 'MINIMUM'}, {'amount': '432.73', 'quartileRanking': 'FIRST'}, {'amount': '454.87', 'quartileRanking': 'MEDIUM'}, {'amount': '588.06', 'quartileRanking': 'THIRD'}, {'amount': '691.44', 'quartileRanking': 'MAXIMUM'}]}
# 146 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '74.99', 'quartileRanking': 'MINIMUM'}, {'amount': '441.11', 'quartileRanking': 'FIRST'}, {'amount': '454.27', 'quartileRanking': 'MEDIUM'}, {'amount': '590.53', 'quartileRanking': 'THIRD'}, {'amount': '696.32', 'quartileRanking': 'MAXIMUM'}]}
# 147 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '75.70', 'quartileRanking': 'MINIMUM'}, {'amount': '452.59', 'quartileRanking': 'FIRST'}, {'amount': '468.65', 'quartileRanking': 'MEDIUM'}, {'amount': '606.97', 'quartileRanking': 'THIRD'}, {'amount': '701.69', 'quartileRanking': 'MAXIMUM'}]}
# 148 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '75.92', 'quartileRanking': 'MINIMUM'}, {'amount': '454.29', 'quartileRanking': 'FIRST'}, {'amount': '464.43', 'quartileRanking': 'MEDIUM'}, {'amount': '598.70', 'quartileRanking': 'THIRD'}, {'amount': '716.11', 'quartileRanking': 'MAXIMUM'}]}
# 149 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '76.68', 'quartileRanking': 'MINIMUM'}, {'amount': '425.01', 'quartileRanking': 'FIRST'}, {'amount': '477.67', 'quartileRanking': 'MEDIUM'}, {'amount': '604.24', 'quartileRanking': 'THIRD'}, {'amount': '725.50', 'quartileRanking': 'MAXIMUM'}]}
# 150 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '74.78', 'quartileRanking': 'MINIMUM'}, {'amount': '388.26', 'quartileRanking': 'FIRST'}, {'amount': '399.69', 'quartileRanking': 'MEDIUM'}, {'amount': '557.81', 'quartileRanking': 'THIRD'}, {'amount': '665.34', 'quartileRanking': 'MAXIMUM'}]}
# 151 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '74.78', 'quartileRanking': 'MINIMUM'}, {'amount': '375.54', 'quartileRanking': 'FIRST'}, {'amount': '401.54', 'quartileRanking': 'MEDIUM'}, {'amount': '554.52', 'quartileRanking': 'THIRD'}, {'amount': '661.32', 'quartileRanking': 'MAXIMUM'}]}
# 152 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '74.78', 'quartileRanking': 'MINIMUM'}, {'amount': '388.86', 'quartileRanking': 'FIRST'}, {'amount': '418.60', 'quartileRanking': 'MEDIUM'}, {'amount': '557.53', 'quartileRanking': 'THIRD'}, {'amount': '666.41', 'quartileRanking': 'MAXIMUM'}]}
# 153 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '74.99', 'quartileRanking': 'MINIMUM'}, {'amount': '396.91', 'quartileRanking': 'FIRST'}, {'amount': '448.14', 'quartileRanking': 'MEDIUM'}, {'amount': '605.49', 'quartileRanking': 'THIRD'}, {'amount': '676.41', 'quartileRanking': 'MAXIMUM'}]}
# 154 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '75.54', 'quartileRanking': 'MINIMUM'}, {'amount': '392.25', 'quartileRanking': 'FIRST'}, {'amount': '447.39', 'quartileRanking': 'MEDIUM'}, {'amount': '591.67', 'quartileRanking': 'THIRD'}, {'amount': '676.99', 'quartileRanking': 'MAXIMUM'}]}
# 155 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '76.92', 'quartileRanking': 'MINIMUM'}, {'amount': '415.93', 'quartileRanking': 'FIRST'}, {'amount': '488.36', 'quartileRanking': 'MEDIUM'}, {'amount': '569.14', 'quartileRanking': 'THIRD'}, {'amount': '673.48', 'quartileRanking': 'MAXIMUM'}]}
# No data for EWR to IAH on 2025-01-31
# No data for EWR to IAH on 2025-02-28
# No data for EWR to IAH on 2025-03-31
# No data for EWR to IAH on 2025-04-30
# No data for EWR to IAH on 2025-05-31
# No data for EWR to IAH on 2025-06-30
# No data for EWR to DEN on 2025-01-31
# No data for EWR to DEN on 2025-02-28
# No data for EWR to DEN on 2025-03-31
# No data for EWR to DEN on 2025-04-30
# No data for EWR to DEN on 2025-05-31
# No data for EWR to DEN on 2025-06-30
# 168 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '70.98', 'quartileRanking': 'MINIMUM'}, {'amount': '443.16', 'quartileRanking': 'FIRST'}, {'amount': '481.70', 'quartileRanking': 'MEDIUM'}, {'amount': '611.20', 'quartileRanking': 'THIRD'}, {'amount': '687.18', 'quartileRanking': 'MAXIMUM'}]}
# 169 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '70.98', 'quartileRanking': 'MINIMUM'}, {'amount': '445.97', 'quartileRanking': 'FIRST'}, {'amount': '479.63', 'quartileRanking': 'MEDIUM'}, {'amount': '612.25', 'quartileRanking': 'THIRD'}, {'amount': '683.24', 'quartileRanking': 'MAXIMUM'}]}
# 170 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '70.98', 'quartileRanking': 'MINIMUM'}, {'amount': '451.99', 'quartileRanking': 'FIRST'}, {'amount': '480.96', 'quartileRanking': 'MEDIUM'}, {'amount': '614.17', 'quartileRanking': 'THIRD'}, {'amount': '685.79', 'quartileRanking': 'MAXIMUM'}]}
# 171 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'EWR'}, 'destination': {'iataCode': 'SFO'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '71.18', 'quartileRanking': 'MINIMUM'}, {'amount': '452.56', 'quartileRanking': 'FIRST'}, {'amount': '505.45', 'quartileRanking': 'MEDIUM'}, {'amount': '630.82', 'quartileRanking': 'THIRD'}, {'amount': '694.72', 'quartileRanking': 'MAXIMUM'}]}
# ...
# 184 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '48.00', 'quartileRanking': 'MINIMUM'}, {'amount': '318.62', 'quartileRanking': 'FIRST'}, {'amount': '347.59', 'quartileRanking': 'MEDIUM'}, {'amount': '348.94', 'quartileRanking': 'THIRD'}, {'amount': '370.33', 'quartileRanking': 'MAXIMUM'}]}
# 185 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '48.49', 'quartileRanking': 'MINIMUM'}, {'amount': '276.39', 'quartileRanking': 'FIRST'}, {'amount': '279.94', 'quartileRanking': 'MEDIUM'}, {'amount': '341.25', 'quartileRanking': 'THIRD'}, {'amount': '368.08', 'quartileRanking': 'MAXIMUM'}]}
# 186 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '66.12', 'quartileRanking': 'MINIMUM'}, {'amount': '421.57', 'quartileRanking': 'FIRST'}, {'amount': '475.79', 'quartileRanking': 'MEDIUM'}, {'amount': '516.77', 'quartileRanking': 'THIRD'}, {'amount': '661.83', 'quartileRanking': 'MAXIMUM'}]}
# 187 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '66.12', 'quartileRanking': 'MINIMUM'}, {'amount': '423.22', 'quartileRanking': 'FIRST'}, {'amount': '485.80', 'quartileRanking': 'MEDIUM'}, {'amount': '529.69', 'quartileRanking': 'THIRD'}, {'amount': '656.76', 'quartileRanking': 'MAXIMUM'}]}
# 188 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '66.12', 'quartileRanking': 'MINIMUM'}, {'amount': '427.89', 'quartileRanking': 'FIRST'}, {'amount': '493.86', 'quartileRanking': 'MEDIUM'}, {'amount': '533.95', 'quartileRanking': 'THIRD'}, {'amount': '659.23', 'quartileRanking': 'MAXIMUM'}]}
# 189 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '66.70', 'quartileRanking': 'MINIMUM'}, {'amount': '433.81', 'quartileRanking': 'FIRST'}, {'amount': '510.75', 'quartileRanking': 'MEDIUM'}, {'amount': '583.93', 'quartileRanking': 'THIRD'}, {'amount': '663.85', 'quartileRanking': 'MAXIMUM'}]}
# 190 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '66.92', 'quartileRanking': 'MINIMUM'}, {'amount': '431.74', 'quartileRanking': 'FIRST'}, {'amount': '518.77', 'quartileRanking': 'MEDIUM'}, {'amount': '579.86', 'quartileRanking': 'THIRD'}, {'amount': '661.51', 'quartileRanking': 'MAXIMUM'}]}
# 191 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'ORD'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '67.61', 'quartileRanking': 'MINIMUM'}, {'amount': '483.83', 'quartileRanking': 'FIRST'}, {'amount': '497.64', 'quartileRanking': 'MEDIUM'}, {'amount': '559.74', 'quartileRanking': 'THIRD'}, {'amount': '671.64', 'quartileRanking': 'MAXIMUM'}]}
# No data for SFO to IAH on 2025-01-31
# No data for SFO to IAH on 2025-02-28
# No data for SFO to IAH on 2025-03-31
# No data for SFO to IAH on 2025-04-30
# No data for SFO to IAH on 2025-05-31
# No data for SFO to IAH on 2025-06-30
# 198 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.06', 'quartileRanking': 'MINIMUM'}, {'amount': '207.35', 'quartileRanking': 'FIRST'}, {'amount': '289.66', 'quartileRanking': 'MEDIUM'}, {'amount': '380.86', 'quartileRanking': 'THIRD'}, {'amount': '455.70', 'quartileRanking': 'MAXIMUM'}]}
# 199 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.06', 'quartileRanking': 'MINIMUM'}, {'amount': '208.14', 'quartileRanking': 'FIRST'}, {'amount': '290.15', 'quartileRanking': 'MEDIUM'}, {'amount': '373.37', 'quartileRanking': 'THIRD'}, {'amount': '457.20', 'quartileRanking': 'MAXIMUM'}]}
# 200 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.06', 'quartileRanking': 'MINIMUM'}, {'amount': '210.67', 'quartileRanking': 'FIRST'}, {'amount': '291.86', 'quartileRanking': 'MEDIUM'}, {'amount': '373.80', 'quartileRanking': 'THIRD'}, {'amount': '460.08', 'quartileRanking': 'MAXIMUM'}]}
# 201 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.28', 'quartileRanking': 'MINIMUM'}, {'amount': '220.77', 'quartileRanking': 'FIRST'}, {'amount': '291.22', 'quartileRanking': 'MEDIUM'}, {'amount': '377.16', 'quartileRanking': 'THIRD'}, {'amount': '462.75', 'quartileRanking': 'MAXIMUM'}]}
# 202 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.26', 'quartileRanking': 'MINIMUM'}, {'amount': '212.83', 'quartileRanking': 'FIRST'}, {'amount': '279.81', 'quartileRanking': 'MEDIUM'}, {'amount': '367.85', 'quartileRanking': 'THIRD'}, {'amount': '458.84', 'quartileRanking': 'MAXIMUM'}]}
# 203 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'DEN'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '44.66', 'quartileRanking': 'MINIMUM'}, {'amount': '195.26', 'quartileRanking': 'FIRST'}, {'amount': '269.79', 'quartileRanking': 'MEDIUM'}, {'amount': '376.82', 'quartileRanking': 'THIRD'}, {'amount': '453.85', 'quartileRanking': 'MAXIMUM'}]}
# 204 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'EWR'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '66.44', 'quartileRanking': 'MINIMUM'}, {'amount': '457.92', 'quartileRanking': 'FIRST'}, {'amount': '458.60', 'quartileRanking': 'MEDIUM'}, {'amount': '584.09', 'quartileRanking': 'THIRD'}, {'amount': '678.18', 'quartileRanking': 'MAXIMUM'}]}
# 205 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'EWR'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '66.44', 'quartileRanking': 'MINIMUM'}, {'amount': '452.69', 'quartileRanking': 'FIRST'}, {'amount': '460.97', 'quartileRanking': 'MEDIUM'}, {'amount': '597.01', 'quartileRanking': 'THIRD'}, {'amount': '681.96', 'quartileRanking': 'MAXIMUM'}]}
# 206 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'EWR'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '66.44', 'quartileRanking': 'MINIMUM'}, {'amount': '455.48', 'quartileRanking': 'FIRST'}, {'amount': '468.58', 'quartileRanking': 'MEDIUM'}, {'amount': '605.06', 'quartileRanking': 'THIRD'}, {'amount': '684.65', 'quartileRanking': 'MAXIMUM'}]}
# 207 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'EWR'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '66.63', 'quartileRanking': 'MINIMUM'}, {'amount': '471.87', 'quartileRanking': 'FIRST'}, {'amount': '482.93', 'quartileRanking': 'MEDIUM'}, {'amount': '587.60', 'quartileRanking': 'THIRD'}, {'amount': '691.16', 'quartileRanking': 'MAXIMUM'}]}
# 208 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'EWR'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '66.85', 'quartileRanking': 'MINIMUM'}, {'amount': '467.97', 'quartileRanking': 'FIRST'}, {'amount': '476.25', 'quartileRanking': 'MEDIUM'}, {'amount': '580.36', 'quartileRanking': 'THIRD'}, {'amount': '694.33', 'quartileRanking': 'MAXIMUM'}]}
# 209 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'SFO'}, 'destination': {'iataCode': 'EWR'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '67.47', 'quartileRanking': 'MINIMUM'}, {'amount': '427.58', 'quartileRanking': 'FIRST'}, {'amount': '470.63', 'quartileRanking': 'MEDIUM'}, {'amount': '612.20', 'quartileRanking': 'THIRD'}, {'amount': '698.61', 'quartileRanking': 'MAXIMUM'}]}
# No data for SFO to IAD on 2025-01-31
# No data for SFO to IAD on 2025-02-28
# No data for SFO to IAD on 2025-03-31
# No data for SFO to IAD on 2025-04-30
# No data for SFO to IAD on 2025-05-31
# No data for SFO to IAD on 2025-06-30
# 216 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'IAD'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-01-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '100.54', 'quartileRanking': 'MINIMUM'}, {'amount': '432.19', 'quartileRanking': 'FIRST'}, {'amount': '449.43', 'quartileRanking': 'MEDIUM'}, {'amount': '611.15', 'quartileRanking': 'THIRD'}, {'amount': '635.04', 'quartileRanking': 'MAXIMUM'}]}
# 217 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'IAD'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-02-28', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '100.54', 'quartileRanking': 'MINIMUM'}, {'amount': '430.24', 'quartileRanking': 'FIRST'}, {'amount': '454.27', 'quartileRanking': 'MEDIUM'}, {'amount': '630.83', 'quartileRanking': 'THIRD'}, {'amount': '653.03', 'quartileRanking': 'MAXIMUM'}]}
# 218 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'IAD'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-03-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '100.54', 'quartileRanking': 'MINIMUM'}, {'amount': '433.24', 'quartileRanking': 'FIRST'}, {'amount': '483.73', 'quartileRanking': 'MEDIUM'}, {'amount': '659.16', 'quartileRanking': 'THIRD'}, {'amount': '664.23', 'quartileRanking': 'MAXIMUM'}]}
# 219 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'IAD'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-04-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '104.10', 'quartileRanking': 'MINIMUM'}, {'amount': '428.52', 'quartileRanking': 'FIRST'}, {'amount': '483.82', 'quartileRanking': 'MEDIUM'}, {'amount': '658.88', 'quartileRanking': 'THIRD'}, {'amount': '668.86', 'quartileRanking': 'MAXIMUM'}]}
# 220 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'IAD'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-05-31', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '104.65', 'quartileRanking': 'MINIMUM'}, {'amount': '424.84', 'quartileRanking': 'FIRST'}, {'amount': '491.99', 'quartileRanking': 'MEDIUM'}, {'amount': '655.11', 'quartileRanking': 'THIRD'}, {'amount': '657.23', 'quartileRanking': 'MAXIMUM'}]}
# 221 {'type': 'itinerary-price-metric', 'origin': {'iataCode': 'IAD'}, 'destination': {'iataCode': 'LAX'}, 'departureDate': '2025-06-30', 'transportType': 'FLIGHT', 'currencyCode': 'USD', 'oneWay': False, 'priceMetrics': [{'amount': '105.97', 'quartileRanking': 'MINIMUM'}, {'amount': '352.44', 'quartileRanking': 'FIRST'}, {'amount': '467.92', 'quartileRanking': 'MEDIUM'}, {'amount': '653.36', 'quartileRanking': 'THIRD'}, {'amount': '685.95', 'quartileRanking': 'MAXIMUM'}]}
# No data for IAD to ORD on 2025-01-31
# No data for IAD to ORD on 2025-02-28
# No data for IAD to ORD on 2025-03-31
# No data for IAD to ORD on 2025-04-30
# No data for IAD to ORD on 2025-05-31
# No data for IAD to ORD on 2025-06-30
# No data for IAD to IAH on 2025-01-31
# No data for IAD to IAH on 2025-02-28
# No data for IAD to IAH on 2025-03-31
# No data for IAD to IAH on 2025-04-30
# No data for IAD to IAH on 2025-05-31
# No data for IAD to IAH on 2025-06-30
# No data for IAD to DEN on 2025-01-31
# No data for IAD to DEN on 2025-02-28
# No data for IAD to DEN on 2025-03-31
# No data for IAD to DEN on 2025-04-30
# No data for IAD to DEN on 2025-05-31
# No data for IAD to DEN on 2025-06-30
# No data for IAD to EWR on 2025-01-31
# No data for IAD to EWR on 2025-02-28
# No data for IAD to EWR on 2025-03-31
# No data for IAD to EWR on 2025-04-30
# No data for IAD to EWR on 2025-05-31
# No data for IAD to EWR on 2025-06-30
# No data for IAD to SFO on 2025-01-31
# No data for IAD to SFO on 2025-02-28
# No data for IAD to SFO on 2025-03-31
# No data for IAD to SFO on 2025-04-30
# No data for IAD to SFO on 2025-05-31
# No data for IAD to SFO on 2025-06-30
#     origin destination departure_date  price_quantile_minimum  \
# 0      LAX         ORD     2025-01-31                   45.06
# 1      LAX         ORD     2025-02-28                   45.06
# 2      LAX         ORD     2025-03-31                   45.06
# 3      LAX         ORD     2025-04-30                   45.50
# 4      LAX         ORD     2025-05-31                   45.48
# ..     ...         ...            ...                     ...
# 121    IAD         LAX     2025-02-28                  100.54
# 122    IAD         LAX     2025-03-31                  100.54
# 123    IAD         LAX     2025-04-30                  104.10
# 124    IAD         LAX     2025-05-31                  104.65
# 125    IAD         LAX     2025-06-30                  105.97
#
#      price_quantile_low  price_quantile_middle  price_quantile_high  \
# 0                225.63                 323.14               417.43
# 1                231.31                 327.49               428.40
# 2                241.29                 342.78               434.55
# 3                268.53                 364.22               491.29
# 4                269.15                 366.57               494.52
# ..                  ...                    ...                  ...
# 121              430.24                 454.27               630.83
# 122              433.24                 483.73               659.16
# 123              428.52                 483.82               658.88
# 124              424.84                 491.99               655.11
# 125              352.44                 467.92               653.36
#
#      price_quantile_maximum
# 0                    590.70
# 1                    588.68
# 2                    595.02
# 3                    602.88
# 4                    603.35
# ..                      ...
# 121                  653.03
# 122                  664.23
# 123                  668.86
# 124                  657.23
# 125                  685.95
#
# [126 rows x 8 columns]

# %%
df_flight = airport_to_route(df_f)
df_flight = df_flight.iloc[:, 2:]
df_flight['departure_date'] = pd.to_datetime(df_flight['departure_date'])
df_flight['id'] = range(1, len(df_flight)+1)
desired_order = ['id', 'route_id', 'departure_date', 'price_quantile_minimum', 'price_quantile_low', 'price_quantile_middle', 'price_quantile_high', 'price_quantile_maximum']
df_flight = df_flight[desired_order]
# print(df_flight)
df_flight
# Out:
#     origin destination departure_date  price_quantile_minimum  \
# 0      LAX         ORD     2025-01-31                   45.06
# 1      LAX         ORD     2025-02-28                   45.06
# 2      LAX         ORD     2025-03-31                   45.06
# 3      LAX         ORD     2025-04-30                   45.50
# 4      LAX         ORD     2025-05-31                   45.48
# ..     ...         ...            ...                     ...
# 121    IAD         LAX     2025-02-28                  100.54
# 122    IAD         LAX     2025-03-31                  100.54
# 123    IAD         LAX     2025-04-30                  104.10
# 124    IAD         LAX     2025-05-31                  104.65
# 125    IAD         LAX     2025-06-30                  105.97
#
#      price_quantile_low  price_quantile_middle  price_quantile_high  \
# 0                225.63                 323.14               417.43
# 1                231.31                 327.49               428.40
# 2                241.29                 342.78               434.55
# 3                268.53                 364.22               491.29
# 4                269.15                 366.57               494.52
# ..                  ...                    ...                  ...
# 121              430.24                 454.27               630.83
# 122              433.24                 483.73               659.16
# 123              428.52                 483.82               658.88
# 124              424.84                 491.99               655.11
# 125              352.44                 467.92               653.36
#
#      price_quantile_maximum  depar_airport_id  arrival_airport_id  route_id
# 0                    590.70                 1                   2         1
# 1                    588.68                 1                   2         1
# 2                    595.02                 1                   2         1
# 3                    602.88                 1                   2         1
# 4                    603.35                 1                   2         1
# ..                      ...               ...                 ...       ...
# 121                  653.03                 7                   1        37
# 122                  664.23                 7                   1        37
# 123                  668.86                 7                   1        37
# 124                  657.23                 7                   1        37
# 125                  685.95                 7                   1        37
#
# [126 rows x 11 columns]
#       id  route_id departure_date  price_quantile_minimum  price_quantile_low  \
# 0      1         1     2025-01-31                   45.06              225.63
# 1      2         1     2025-02-28                   45.06              231.31
# 2      3         1     2025-03-31                   45.06              241.29
# 3      4         1     2025-04-30                   45.50              268.53
# 4      5         1     2025-05-31                   45.48              269.15
# ..   ...       ...            ...                     ...                 ...
# 121  122        37     2025-02-28                  100.54              430.24
# 122  123        37     2025-03-31                  100.54              433.24
# 123  124        37     2025-04-30                  104.10              428.52
# 124  125        37     2025-05-31                  104.65              424.84
# 125  126        37     2025-06-30                  105.97              352.44
#
#      price_quantile_middle  price_quantile_high  price_quantile_maximum
# 0                   323.14               417.43                  590.70
# 1                   327.49               428.40                  588.68
# 2                   342.78               434.55                  595.02
# 3                   364.22               491.29                  602.88
# 4                   366.57               494.52                  603.35
# ..                     ...                  ...                     ...
# 121                 454.27               630.83                  653.03
# 122                 483.73               659.16                  664.23
# 123                 483.82               658.88                  668.86
# 124                 491.99               655.11                  657.23
# 125                 467.92               653.36                  685.95
#
# [126 rows x 8 columns]

# %%
# # Expand rows
# expanded_rows = []

# # Iterate over each row and expand by days in the month
# for _, row in df_flight.iterrows():
#     last_day = row['departure_date']
#     first_day = last_day.replace(day=1)
    
#     # Generate all days in that month
#     for day in pd.date_range(start=first_day, end=last_day):
#         new_row = row.copy()
#         new_row['departure_date'] = first_day  # replace with first day of month
#         new_row['date'] = day                   # new column with each day of month
#         expanded_rows.append(new_row)


# # Overwrite df_flight with expanded version
# df_flight = pd.DataFrame(expanded_rows)
# df_flight = df_flight.drop(['date'], axis=1)
# df_flight['id'] = range(1, len(df_flight)+1)
# desired_order = ['id', 'route_id', 'departure_date', 'price_quantile_minimum', 'price_quantile_low', 'price_quantile_middle', 'price_quantile_high', 'price_quantile_maximum']
# df_flight = df_flight[desired_order]
# print(df_flight)
# Out:
#        id  route_id departure_date  price_quantile_minimum  \
# 0       1         1     2025-01-01                   45.06
# 0       2         1     2025-01-01                   45.06
# 0       3         1     2025-01-01                   45.06
# 0       4         1     2025-01-01                   45.06
# 0       5         1     2025-01-01                   45.06
# ..    ...       ...            ...                     ...
# 125  3797        37     2025-06-01                  105.97
# 125  3798        37     2025-06-01                  105.97
# 125  3799        37     2025-06-01                  105.97
# 125  3800        37     2025-06-01                  105.97
# 125  3801        37     2025-06-01                  105.97
#
#      price_quantile_low  price_quantile_middle  price_quantile_high  \
# 0                225.63                 323.14               417.43
# 0                225.63                 323.14               417.43
# 0                225.63                 323.14               417.43
# 0                225.63                 323.14               417.43
# 0                225.63                 323.14               417.43
# ..                  ...                    ...                  ...
# 125              352.44                 467.92               653.36
# 125              352.44                 467.92               653.36
# 125              352.44                 467.92               653.36
# 125              352.44                 467.92               653.36
# 125              352.44                 467.92               653.36
#
#      price_quantile_maximum
# 0                    590.70
# 0                    590.70
# 0                    590.70
# 0                    590.70
# 0                    590.70
# ..                      ...
# 125                  685.95
# 125                  685.95
# 125                  685.95
# 125                  685.95
# 125                  685.95
#
# [3801 rows x 8 columns]

# %%
df_flight.to_csv('data/intermediate/flight_month.csv', index=False)

# %%
df_flight = pd.read_csv('data/intermediate/flight_month.csv')
df_flight
# Out:
#       id  route_id departure_date  price_quantile_minimum  price_quantile_low  \
# 0      1         1     2025-01-31                   45.06              225.63
# 1      2         1     2025-02-28                   45.06              231.31
# 2      3         1     2025-03-31                   45.06              241.29
# 3      4         1     2025-04-30                   45.50              268.53
# 4      5         1     2025-05-31                   45.48              269.15
# ..   ...       ...            ...                     ...                 ...
# 121  122        37     2025-02-28                  100.54              430.24
# 122  123        37     2025-03-31                  100.54              433.24
# 123  124        37     2025-04-30                  104.10              428.52
# 124  125        37     2025-05-31                  104.65              424.84
# 125  126        37     2025-06-30                  105.97              352.44
#
#      price_quantile_middle  price_quantile_high  price_quantile_maximum
# 0                   323.14               417.43                  590.70
# 1                   327.49               428.40                  588.68
# 2                   342.78               434.55                  595.02
# 3                   364.22               491.29                  602.88
# 4                   366.57               494.52                  603.35
# ..                     ...                  ...                     ...
# 121                 454.27               630.83                  653.03
# 122                 483.73               659.16                  664.23
# 123                 483.82               658.88                  668.86
# 124                 491.99               655.11                  657.23
# 125                 467.92               653.36                  685.95
#
# [126 rows x 8 columns]

# %%
from pandas.tseries.offsets import MonthEnd

def expand_to_full_month(row):
    start_date = row['departure_date']
    end_date = start_date + MonthEnd(0)  # get last day of the month
    
    # Generate all dates from start_date to end_date inclusive
    all_dates = pd.date_range(start=start_date, end=end_date)
    
    # Repeat the row for each day and assign the dates
    expanded_rows = pd.DataFrame({
        **{col: [row[col]] * len(all_dates) for col in row.index if col != 'departure_date'},
        'departure_date': all_dates
    })
    
    return expanded_rows

# Apply to all rows and concatenate
expanded_df = pd.concat(df_flight.apply(expand_to_full_month, axis=1).to_list(), ignore_index=True)

print(expanded_df)
# Out:
#      price_quantile_minimum  price_quantile_low  price_quantile_middle  \
# 0                     45.06              225.63                 323.14
# 1                     45.06              231.31                 327.49
# 2                     45.06              241.29                 342.78
# 3                     45.50              268.53                 364.22
# 4                     45.48              269.15                 366.57
# ..                      ...                 ...                    ...
# 121                  100.54              430.24                 454.27
# 122                  100.54              433.24                 483.73
# 123                  104.10              428.52                 483.82
# 124                  104.65              424.84                 491.99
# 125                  105.97              352.44                 467.92
#
#      price_quantile_high  price_quantile_maximum  depar_airport_id  \
# 0                 417.43                  590.70                 1
# 1                 428.40                  588.68                 1
# 2                 434.55                  595.02                 1
# 3                 491.29                  602.88                 1
# 4                 494.52                  603.35                 1
# ..                   ...                     ...               ...
# 121               630.83                  653.03                 7
# 122               659.16                  664.23                 7
# 123               658.88                  668.86                 7
# 124               655.11                  657.23                 7
# 125               653.36                  685.95                 7
#
#      arrival_airport_id  route_id departure_date
# 0                     2         1     2025-01-31
# 1                     2         1     2025-02-28
# 2                     2         1     2025-03-31
# 3                     2         1     2025-04-30
# 4                     2         1     2025-05-31
# ..                  ...       ...            ...
# 121                   1        37     2025-02-28
# 122                   1        37     2025-03-31
# 123                   1        37     2025-04-30
# 124                   1        37     2025-05-31
# 125                   1        37     2025-06-30
#
# [126 rows x 9 columns]

# %%
# import pandas as pd


# def parse_flight_price(flight_offers: list) -> pd.DataFrame:
#     rows = []

#     for offer in flight_offers:
#         total_price = offer.get("price", {}).get("grandTotal")
#         traveler_pricing = offer.get("travelerPricings", [{}])[0]
#         cabin = traveler_pricing.get("fareDetailsBySegment", [{}])[0].get("cabin")

#         for itinerary in offer.get("itineraries", []):
#             for segment in itinerary.get("segments", []):
#                 row = {
#                     "departure_iata": segment["departure"]["iataCode"],
#                     "arrival_iata": segment["arrival"]["iataCode"],
#                     "departure_time": segment["departure"]["at"],
#                     "arrival_time": segment["arrival"]["at"],
#                     "carrier_code": segment["carrierCode"],
#                     "total_price": total_price,
#                     "cabin": cabin
#                 }
#                 rows.append(row)

#     return pd.DataFrame(rows)

# df = parse_flight_price(response.data)
# print(df)

# %% [markdown]
# ## Database setting

# %%
# load all data we need
df_city = pd.read_csv('data/intermediate/city.csv')
df_weather = pd.read_csv('data/intermediate/weather.csv')
df_iata = pd.read_csv('data/intermediate/city_airport.csv')
routes_df = pd.read_csv('data/intermediate/routes.csv')
df_flight = pd.read_csv('data/intermediate/flight_month.csv')

# %%
df_flight["departure_date"] = pd.to_datetime(df_flight["departure_date"])

# %%
df_iata
# Out:
#    Unnamed: 0  id iata_code  city_id
# 0           0   1       LAX        1
# 1           1   2       ORD        2
# 2           2   3       IAH        3
# 3           3   4       DEN        4
# 4           4   5       EWR        5
# 5           5   6       SFO        6
# 6           6   7       IAD        7

# %%
routes_df
# Out:
#     id  depar_airport_id  desti_airport_id
# 0    1                 1                 2
# 1    2                 1                 3
# 2    3                 1                 4
# 3    4                 1                 5
# 4    5                 1                 6
# 5    6                 1                 7
# 6    7                 2                 1
# 7    8                 2                 3
# 8    9                 2                 4
# 9   10                 2                 5
# 10  11                 2                 6
# 11  12                 2                 7
# 12  13                 3                 1
# 13  14                 3                 2
# 14  15                 3                 4
# 15  16                 3                 5
# 16  17                 3                 6
# 17  18                 3                 7
# 18  19                 4                 1
# 19  20                 4                 2
# 20  21                 4                 3
# 21  22                 4                 5
# 22  23                 4                 6
# 23  24                 4                 7
# 24  25                 5                 1
# 25  26                 5                 2
# 26  27                 5                 3
# 27  28                 5                 4
# 28  29                 5                 6
# 29  30                 5                 7
# 30  31                 6                 1
# 31  32                 6                 2
# 32  33                 6                 3
# 33  34                 6                 4
# 34  35                 6                 5
# 35  36                 6                 7
# 36  37                 7                 1
# 37  38                 7                 2
# 38  39                 7                 3
# 39  40                 7                 4
# 40  41                 7                 5
# 41  42                 7                 6

# %%
df_flight[df_flight["route_id"] < 7].groupby(['departure_date']).mean()
# Out:
#                   id  route_id  price_quantile_minimum  price_quantile_low  \
# departure_date
# 2025-01-31      16.0       3.5               55.645000          280.160000
# 2025-02-28      17.0       3.5               55.645000          281.906667
# 2025-03-31      18.0       3.5               55.645000          288.868333
# 2025-04-30      19.0       3.5               56.198333          302.266667
# 2025-05-31      20.0       3.5               56.315000          302.296667
# 2025-06-30      21.0       3.5               57.636667          293.726667
#
#                 price_quantile_middle  price_quantile_high  \
# departure_date
# 2025-01-31                 334.040000           395.523333
# 2025-02-28                 339.303333           402.406667
# 2025-03-31                 351.393333           412.278333
# 2025-04-30                 367.860000           435.575000
# 2025-05-31                 376.543333           438.173333
# 2025-06-30                 355.403333           436.376667
#
#                 price_quantile_maximum
# departure_date
# 2025-01-31                  515.445000
# 2025-02-28                  514.390000
# 2025-03-31                  520.261667
# 2025-04-30                  527.133333
# 2025-05-31                  533.805000
# 2025-06-30                  528.095000

# %%
df_flight[df_flight["departure_date"] == pd.to_datetime("2025-05-31")].sort_values(by="price_quantile_middle", ascending=False)
# Out:
#       id  route_id departure_date  price_quantile_minimum  price_quantile_low  \
# 34    35         6     2025-05-31                   87.57              359.83
# 58    59        11     2025-05-31                   71.88              404.28
# 106  107        32     2025-05-31                   66.92              431.74
# 94    95        29     2025-05-31                   71.40              444.96
# 124  125        37     2025-05-31                  104.65              424.84
# 22    23         4     2025-05-31                   69.57              424.87
# 118  119        35     2025-05-31                   66.85              467.97
# 82    83        25     2025-05-31                   75.92              454.29
# 88    89        26     2025-05-31                   75.54              392.25
# 4      5         1     2025-05-31                   45.48              269.15
# 100  101        31     2025-05-31                   48.00              318.62
# 28    29         5     2025-05-31                   47.97              300.09
# 64    65        13     2025-05-31                   44.03              264.31
# 76    77        20     2025-05-31                   75.38              214.74
# 40    41         7     2025-05-31                   46.32              261.49
# 70    71        19     2025-05-31                   43.48              236.26
# 10    11         2     2025-05-31                   42.98              260.15
# 112  113        34     2025-05-31                   44.26              212.83
# 16    17         3     2025-05-31                   44.32              199.69
# 52    53         9     2025-05-31                   44.67              179.62
# 46    47         8     2025-05-31                   41.28              182.73
#
#      price_quantile_middle  price_quantile_high  price_quantile_maximum
# 34                  557.96               602.62                  715.37
# 58                  540.49               556.52                  623.34
# 106                 518.77               579.86                  661.51
# 94                  506.72               624.43                  706.08
# 124                 491.99               655.11                  657.23
# 22                  478.27               543.92                  670.99
# 118                 476.25               580.36                  694.33
# 82                  464.43               598.70                  716.11
# 88                  447.39               591.67                  676.99
# 4                   366.57               494.52                  603.35
# 100                 347.59               348.94                  370.33
# 28                  326.12               331.62                  383.95
# 64                  326.11               390.82                  470.00
# 76                  308.95               354.55                  440.06
# 40                  280.73               400.88                  541.96
# 70                  280.64               308.87                  388.53
# 10                  279.94               372.57                  419.20
# 112                 279.81               367.85                  458.84
# 16                  250.40               283.79                  409.97
# 52                  234.15               344.47                  422.64
# 46                  210.90               366.40                  389.34

# %%
df_weather[df_weather['alert'] == True]
# Out:
#        id        date  city_id  weather_id       weather  alert
# 313   314  2025-05-16        2         502          Rain   True
# 347   348  2025-06-19        2         503          Rain   True
# 381   382  2025-01-27        3         502          Rain   True
# 404   405  2025-02-19        3         211  Thunderstorm   True
# 405   406  2025-02-19        3         502          Rain   True
# 409   410  2025-02-23        3         741           Fog   True
# 445   446  2025-03-29        3         211  Thunderstorm   True
# 758   244  2025-03-06        5         502          Rain   True
# 811   297  2025-04-27        5         502          Rain   True
# 905   391  2025-02-05        6         502          Rain   True
# 1134  620  2025-04-01        7         202  Thunderstorm   True
# 1135  621  2025-04-01        7         502          Rain   True
# 1196  682  2025-05-31        7         502          Rain   True
# 1210  696  2025-06-14        7         211  Thunderstorm   True

# %%
import duckdb as dd

# Create an in-memory DuckDB connection
con = dd.connect('data/static.duckdb')

# %%
con.execute('SELECT f.price_quartile_middle FROM flight f JOIN route r ON f.route_id = r.id JOIN     nearest_airport depar_airport ON r.depar_airport_id = depar_airport.id JOIN     nearest_airport desti_airport ON r.desti_airport_id = desti_airport.id JOIN     city depar_city ON depar_airport.city_id = depar_city.id JOIN     city desti_city ON desti_airport.city_id = desti_city.id WHERE     depar_city.city_name = \'los angeles\'     AND desti_city.city_name = \'new york\' ORDER BY     f.departure_date DESC LIMIT 5;').fetchdf()
# Out:
# Empty DataFrame
# Columns: [price_quartile_middle]
# Index: []

# %%
# optional: clear database
drop_order = ["flight", "weather", "route", "nearest_airport", "city"]
for table_name in drop_order:
    con.execute(f"DROP TABLE IF EXISTS {table_name}")

# %%
# Read SQL schema from file
with open("schema/static.sql", "r") as f:
    sql_script = f.read()

# Execute the schema to build tables
con.execute(sql_script)
# drop a useless table
con.execute("DROP TABLE IF EXISTS location")

# Verify tables were created
print(con.execute("SHOW TABLES").fetchdf())
# Out:
#               name
# 0             city
# 1           flight
# 2  nearest_airport
# 3            route
# 4          weather

# %%
## insert locations info
# Register and insert into the location table
con.register("df_city", df_city)
con.execute("INSERT INTO city (id, city_name) SELECT id, city_name FROM df_city")

con.execute("PRAGMA table_info('city')").fetchdf()
# Out:
#    cid       name     type  notnull dflt_value     pk
# 0    0         id   BIGINT     True       None   True
# 1    1  city_name  VARCHAR     True       None  False

# %%
## get all key info
# con.execute("SELECT * FROM duckdb_constraints()").fetchdf()

# %%
# df_weather = df_weather.iloc[:, 1:]

# %%
# df_weather_all['id'] = range(1, len(df_weather_all)+1)

# %%
df_weather_all
# Out:
#       id        date  city_id  weather_id weather  alert
# 0      1  2025-01-01        1         804  Clouds  False
# 1      2  2025-01-02        1         800   Clear  False
# 2      3  2025-01-03        1         800   Clear  False
# 3      4  2025-01-04        1         800   Clear  False
# 4      5  2025-01-05        1         804  Clouds  False
# ..   ...         ...      ...         ...     ...    ...
# 8   1229  2025-06-13        3         800   Clear  False
# 9   1230  2025-06-14        3         800   Clear  False
# 10  1231  2025-06-15        3         803  Clouds  False
# 11  1232  2025-06-16        3         804  Clouds  False
# 12  1233  2025-06-17        3         803  Clouds  False
#
# [1233 rows x 6 columns]

# %%
### insert weather data
con.register("df_weather_all", df_weather_all)
con.execute("INSERT INTO weather SELECT * FROM df_weather_all")
con.execute("PRAGMA table_info('weather')").fetchdf()
# Out:
#    cid        name     type  notnull dflt_value     pk
# 0    0          id   BIGINT     True       None   True
# 1    1        date     DATE     True       None  False
# 2    2     city_id   BIGINT     True       None  False
# 3    3  weather_id   BIGINT     True       None  False
# 4    4     weather  VARCHAR     True       None  False
# 5    5       alert  BOOLEAN     True       None  False

# %%
df_iata = df_iata.iloc[:, 1:]

# %%
### insert airport data
con.register("df_iata", df_iata)
con.execute("INSERT INTO nearest_airport SELECT * FROM df_iata")
con.execute("PRAGMA table_info('nearest_airport')").fetchdf()
# Out:
#    cid       name     type  notnull dflt_value     pk
# 0    0         id   BIGINT     True       None   True
# 1    1  iata_code  VARCHAR     True       None  False
# 2    2    city_id   BIGINT     True       None  False

# %%
routes_df = routes_df.iloc[:, 1:]

# %%
### insert route data
con.register("routes_df", routes_df)
con.execute("INSERT INTO route SELECT * FROM routes_df")
con.execute("PRAGMA table_info('route')").fetchdf()
# Out:
#    cid              name    type  notnull dflt_value     pk
# 0    0                id  BIGINT     True       None   True
# 1    1  depar_airport_id  BIGINT     True       None  False
# 2    2  desti_airport_id  BIGINT     True       None  False

# %%
# df_flight

# %%
### insert holiday data
con.register("df_flight", df_flight)
con.execute("INSERT INTO flight SELECT * FROM df_flight")
con.execute("PRAGMA table_info('flight')").fetchdf()
# Out:
#    cid                    name      type  notnull dflt_value     pk
# 0    0                      id    BIGINT     True       None   True
# 1    1                route_id    BIGINT     True       None  False
# 2    2          departure_date      DATE     True       None  False
# 3    3  price_quartile_minimum  SMALLINT     True       None  False
# 4    4      price_quartile_low  SMALLINT     True       None  False
# 5    5   price_quartile_middle  SMALLINT     True       None  False
# 6    6     price_quartile_high  SMALLINT     True       None  False
# 7    7  price_quartile_maximum  SMALLINT     True       None  False

# %%
tables = con.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()

for (table_name,) in tables:
    print(f"Table: {table_name}")
    rows = con.execute(f"SELECT * FROM {table_name} LIMIT 3").fetchdf()
    print(rows)
    print("\n" + "-"*40 + "\n")
# Out:
# Table: city
#    id    city_name
# 0   1  los angeles
# 1   2      chicago
# 2   3      houston
#
# ----------------------------------------
#
# Table: flight
#    id  route_id departure_date  price_quartile_minimum  price_quartile_low  \
# 0   1         1     2025-01-31                      45                 226
# 1   2         1     2025-02-28                      45                 231
# 2   3         1     2025-03-31                      45                 241
#
#    price_quartile_middle  price_quartile_high  price_quartile_maximum
# 0                    323                  417                     591
# 1                    327                  428                     589
# 2                    343                  435                     595
#
# ----------------------------------------
#
# Table: nearest_airport
#    id iata_code  city_id
# 0   1       LAX        1
# 1   2       ORD        2
# 2   3       IAH        3
#
# ----------------------------------------
#
# Table: route
#    id  depar_airport_id  desti_airport_id
# 0   1                 1                 2
# 1   2                 1                 3
# 2   3                 1                 4
#
# ----------------------------------------
#
# Table: weather
#    id       date  city_id  weather_id weather  alert
# 0   1 2025-01-01        1         804  Clouds  False
# 1   2 2025-01-02        1         800   Clear  False
# 2   3 2025-01-03        1         800   Clear  False
#
# ----------------------------------------

# %%
# Get all table names
tables = con.execute("SHOW TABLES").fetchall()
tables = [t[0] for t in tables]

# Print row count for each table
for table in tables:
    count = con.execute(f"SELECT COUNT(*) FROM {table}").fetchone()[0]
    print(f"Table '{table}' has {count} rows.")
# Out:
# Table 'city' has 7 rows.
# Table 'df_city' has 7 rows.
# Table 'df_flight' has 126 rows.
# Table 'df_iata' has 7 rows.
# Table 'df_weather_all' has 1233 rows.
# Table 'flight' has 126 rows.
# Table 'nearest_airport' has 7 rows.
# Table 'route' has 42 rows.
# Table 'routes_df' has 42 rows.
# Table 'weather' has 1233 rows.

# %%
# end the database
# con.commit()  # Optional, but ensures changes are flushed
con.close()   # Closes the DB and safely handles the WAL
